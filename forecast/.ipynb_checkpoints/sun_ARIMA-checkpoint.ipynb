# %%
ATTR_NOW = 'sunshine'

# %%
attr_dict = {
    'min_temp': ('mnt', 'Temperatur minimum'),
    'max_temp': ('mxt', 'Temperatur maksimum'),
    'avg_temp': ('avgt', 'Temperatur rata-rata'),
    'avg_humidity': ('hum', 'Kelembapan rata-rata'),
    'sunshine': ('sun', 'Penyinaran matahari'),
    'rainfall': ('rain', 'Curah hujan'),
}

ATTR_CODE = attr_dict[ATTR_NOW][0]
ATTR_NAME = attr_dict[ATTR_NOW][1]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.tsa.stattools as sts
import statsmodels.graphics.tsaplots as sgt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose

from pmdarima.arima import auto_arima, ndiffs, nsdiffs

from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

import scipy.stats as stats
from scipy.stats import boxcox
from scipy.special import inv_boxcox
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../attributes_dataset/sunshine.csv')
df.date = pd.to_datetime(df.date, format='%Y-%m-%d')
df.set_index('date', inplace=True)
df.head()
# Out:
#             sunshine
# date
# 2016-01-01       4.1
# 2016-01-02       8.6
# 2016-01-03       8.4
# 2016-01-04       3.3
# 2016-01-05       3.5

# %% [markdown]
# # Splitting Data

# %%
train_ratio = int(len(df) * 0.9)

# %%
dtrain = df.iloc[:train_ratio]
dtest = df.iloc[train_ratio:]

# %%
print(dtrain.shape)
print(dtest.shape)
# Out:
# (2053, 1)
# (229, 1)

# %% [markdown]
# # Visualisasi ACF dan PACF

# %%
lags = 40
fig, ax = plt.subplots(1,2,figsize=(11,3))
plt.suptitle(ATTR_NAME, fontsize=14)
sgt.plot_acf(dtrain, lags=lags, zero=False, ax=ax[0])
sgt.plot_pacf(dtrain, lags=lags, zero=False, ax=ax[1])
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.plot(dtrain)

# %%
plt.figure(figsize=(18,4))
plt.plot(dtrain.loc['2017-01-01':'2018-01-01'])

# %%
dtrain.head(5)
# Out:
#             sunshine
# date
# 2016-01-01       4.1
# 2016-01-02       8.6
# 2016-01-03       8.4
# 2016-01-04       3.3
# 2016-01-05       3.5

# %% [markdown]
# # Stasionary Test (dickey fuller)

# %%
adf = sts.adfuller(dtrain)
print(f'ADF p values\t\t: {adf[1]}')
print(f'ADF statistic values\t: {adf[0]}')
print(f'ADF critical values\t: {adf[4]}')
# Out:
# ADF p values		: 2.3911669690746513e-19
# ADF statistic values	: -10.770496827466571
# ADF critical values	: {'1%': -3.4335532932197967, '5%': -2.8629550592036455, '10%': -2.5675233142202276}

# %%
# p-value < 0.05 tidak stasioner
sts.kpss(dtrain, regression='ct')
# Out:
# (0.2915301930743055,
#  0.01,
#  26,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
d_value = ndiffs(dtrain, test='kpss')
d_value
# Out:
# 1

# %% [markdown]
# # Levene Test

# %%
len_dtrain = len(dtrain)
levgrp_1 = dtrain.sunshine.iloc[int(0.2*len_dtrain):int(0.6*len_dtrain)]
levgrp_2 = dtrain.sunshine.iloc[:int(0.4*len_dtrain)]
levgrp_3 = dtrain.sunshine.iloc[int(0.8*len_dtrain):]
levgrp_4 = dtrain.sunshine.iloc[int(0.2*len_dtrain):int(0.9*len_dtrain)]

# %%
#levene p-value > 0.05 == varian stasioner

levene_val = stats.levene(levgrp_1, levgrp_2, levgrp_3, levgrp_4, center='mean')
print(levene_val)
if levene_val[1] > 0.05:
    print('Varian Stasioner')
else:
    print('Varian Tidak Stasioner')
# Out:
# LeveneResult(statistic=0.6582457633197056, pvalue=0.5777242440245212)
# Varian Stasioner

# %% [markdown]
# ### Menurut KPSS test, yang menguji Trend Stationarity.. data perlu dilakukan differencing 1 kali

# %% [markdown]
# ### Data tidak bisa melalui transformasi boxcox karena mengandung nilai 0

# %% [markdown]
# # Auto Arima Model

# %%
train_exg = pd.read_csv('../R_resource/sunshine_train_exog182.csv')
train_exg = train_exg.drop(columns='Unnamed: 0')

# %%
test_exg = pd.read_csv('../R_resource/sunshine_test_exog182.csv')
test_exg = test_exg.drop(columns='Unnamed: 0')

# %%
print(train_exg.shape)
print(test_exg.shape)
# Out:
# (2053, 364)
# (229, 364)

# %% [raw]
# %%time
# model = auto_arima(dtrain, exogenous=train_exg, trace=True, stepwise=True,
#                        max_p=7, max_q=7, d=1)

# %%
model_loc = f'ARIMA_models/{ATTR_NOW}.pkl'

# %% [raw]
# ## saving model
#
# with open(model_loc, 'wb') as pkl:
#     pickle.dump(model, pkl)

# %%
## open the model

with open(model_loc, 'rb') as pkl:
    model = pickle.load(pkl)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2053
# Model:               SARIMAX(1, 1, 2)   Log Likelihood               -4612.099
# Date:                Mon, 08 Aug 2022   AIC                           9960.197
# Time:                        15:14:58   BIC                          12030.775
# Sample:                             0   HQIC                         10719.483
#                                - 2053
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# S1-365        -0.3449      0.224     -1.540      0.123      -0.784       0.094
# C1-365        -0.3374      0.225     -1.499      0.134      -0.779       0.104
# S2-365         0.3957      0.172      2.300      0.021       0.058       0.733
# C2-365        -0.3063      0.187     -1.640      0.101      -0.672       0.060
# S3-365        -0.1415      0.171     -0.828      0.408      -0.477       0.194
# C3-365         0.2582      0.167      1.550      0.121      -0.068       0.585
# S4-365        -0.2733      0.162     -1.692      0.091      -0.590       0.043
# C4-365        -0.3936      0.167     -2.362      0.018      -0.720      -0.067
# S5-365         0.1910      0.162      1.177      0.239      -0.127       0.509
# C5-365        -0.0621      0.161     -0.387      0.699      -0.377       0.253
# S6-365        -0.0946      0.161     -0.587      0.557      -0.410       0.221
# C6-365         0.0615      0.160      0.386      0.700      -0.251       0.374
# S7-365         0.0472      0.151      0.312      0.755      -0.249       0.344
# C7-365         0.0191      0.167      0.114      0.909      -0.309       0.347
# S8-365         0.1261      0.163      0.773      0.440      -0.194       0.446
# C8-365         0.1459      0.153      0.954      0.340      -0.154       0.446
# S9-365        -0.0186      0.155     -0.120      0.904      -0.322       0.285
# C9-365        -0.1377      0.159     -0.868      0.385      -0.449       0.173
# S10-365       -0.1422      0.157     -0.904      0.366      -0.450       0.166
# C10-365       -0.1009      0.154     -0.655      0.512      -0.403       0.201
# S11-365        0.1222      0.154      0.792      0.429      -0.180       0.425
# C11-365        0.0578      0.155      0.373      0.709      -0.245       0.361
# S12-365        0.0163      0.155      0.105      0.916      -0.288       0.320
# C12-365       -0.1104      0.152     -0.727      0.467      -0.408       0.187
# S174-365       0.0545      0.069      0.790      0.430      -0.081       0.190
# C174-365      -0.0523      0.073     -0.714      0.475      -0.196       0.091
# S175-365       0.0397      0.070      0.570      0.569      -0.097       0.176
# C175-365       0.0560      0.073      0.771      0.441      -0.086       0.198
# S176-365      -0.0841      0.070     -1.195      0.232      -0.222       0.054
# C176-365      -0.1724      0.072     -2.395      0.017      -0.313      -0.031
# S177-365      -0.0363      0.070     -0.519      0.603      -0.173       0.101
# C177-365       0.0092      0.072      0.128      0.898      -0.132       0.150
# S178-365      -0.0086      0.074     -0.116      0.908      -0.154       0.137
# C178-365      -0.0755      0.068     -1.108      0.268      -0.209       0.058
# S179-365       0.1148      0.071      1.609      0.108      -0.025       0.255
# C179-365       0.0098      0.071      0.138      0.891      -0.130       0.149
# S180-365      -0.1177      0.075     -1.572      0.116      -0.265       0.029
# C180-365      -0.0367      0.067     -0.545      0.586      -0.169       0.095
# S181-365       0.0358      0.070      0.510      0.610      -0.102       0.173
# C181-365      -0.0499      0.072     -0.695      0.487      -0.191       0.091
# S182-365      -0.0695      0.071     -0.978      0.328      -0.209       0.070
# C182-365      -0.0383      0.071     -0.538      0.590      -0.178       0.101
# ar.L1          0.5575      0.058      9.622      0.000       0.444       0.671
# ma.L1         -1.2018      0.068    -17.799      0.000      -1.334      -1.069
# ma.L2          0.2144      0.065      3.281      0.001       0.086       0.342
# sigma2         5.2389      0.217     24.170      0.000       4.814       5.664
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                12.39
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.93   Skew:                            -0.02
# Prob(H) (two-sided):                  0.34   Kurtosis:                         2.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model.plot_diagnostics(figsize=(15,8));

# %%
def execute_forecast(pred, df_actual):
    results = pd.DataFrame(data={'date': df_actual.index, 'Predictions': pred, 'Actuals': df_actual[ATTR_NOW].values})
    results.set_index('date', inplace=True)
    
    plt.figure(figsize=(18,8))
    plt.title(f'Peramalan {ATTR_NAME} ARIMA')
    plt.plot(results.Predictions, 'b', label='Predictions')
    plt.plot(results.Actuals, 'r--', label='Actuals')
    plt.legend()
    plt.show
    
    MAE = mean_absolute_error(results.Actuals, results.Predictions)
    RMSE = sqrt(mean_squared_error(results.Actuals, results.Predictions))
    print(f'Mean Absolute Error is\t\t: {MAE}')
    print(f'Root Mean Squared Error is\t: {RMSE}')
    
    return results, MAE, RMSE

# %%
predictions = model.predict(n_periods = len(dtest), exogenous=test_exg)

# %%
results, __, __ = execute_forecast(predictions, dtest)
# Out:
# Mean Absolute Error is		: 2.5806533474358644
# Root Mean Squared Error is	: 3.0635048729987426

# %% [markdown]
# # Period Forecasting

# %%
def period_forecast(model_loc, period, data, exog):
    with open(model_loc, 'rb') as pkl:
        model = pickle.load(pkl) 
    predictions = []
    prog_count = 0
    for index in np.arange(0, len(data), period):
        if index+period > len(data) - 1:
            period = int(len(data) - index)
        print(f'Forecasting {period}-step from index {index}')
        results = model.predict(n_periods=period, exogenous=exog.iloc[index:index+period])
        for result in results:
            prog_count += 1
            predictions.append(result)
            print(f"result: {result}\t\tprocess: {prog_count}/{len(data)}")
        print('Updating the model...')
        model.update(data.iloc[index:index+period], exogenous=exog.iloc[index:index+period])
            
    return np.array(predictions)

# %% [markdown]
# ### Forecast scenario 1 : 1 time step

# %%
# %%time
sc1_forecast = period_forecast(model_loc, 1, dtest, test_exg)
# Out:
# Forecasting 1-step from index 0
# result: 6.701558472959656		process: 1/229
# Updating the model...
# Forecasting 1-step from index 1
# result: 4.875891898617069		process: 2/229
# Updating the model...
# Forecasting 1-step from index 2
# result: 5.422811465489969		process: 3/229
# Updating the model...
# Forecasting 1-step from index 3
# result: 7.584502791238142		process: 4/229
# Updating the model...
# Forecasting 1-step from index 4
# result: 7.452046351660595		process: 5/229
# Updating the model...
# Forecasting 1-step from index 5
# result: 8.060391757684053		process: 6/229
# Updating the model...
# Forecasting 1-step from index 6
# result: 6.263256374259579		process: 7/229
# Updating the model...
# Forecasting 1-step from index 7
# result: 7.340916329306797		process: 8/229
# Updating the model...
# Forecasting 1-step from index 8
# result: 5.016236607305418		process: 9/229
# Updating the model...
# Forecasting 1-step from index 9
# result: 4.743452177955655		process: 10/229
# Updating the model...
# Forecasting 1-step from index 10
# result: 5.9804498196688325		process: 11/229
# Updating the model...
# Forecasting 1-step from index 11
# result: 3.2307703871496383		process: 12/229
# Updating the model...
# Forecasting 1-step from index 12
# result: 4.173041837646505		process: 13/229
# Updating the model...
# Forecasting 1-step from index 13
# result: 6.256925626995988		process: 14/229
# Updating the model...
# Forecasting 1-step from index 14
# result: 5.073919158895393		process: 15/229
# Updating the model...
# Forecasting 1-step from index 15
# result: 3.8045982918716916		process: 16/229
# Updating the model...
# Forecasting 1-step from index 16
# result: 6.4480919491109585		process: 17/229
# Updating the model...
# Forecasting 1-step from index 17
# result: 5.920874238358925		process: 18/229
# Updating the model...
# Forecasting 1-step from index 18
# result: 8.127068883172573		process: 19/229
# Updating the model...
# Forecasting 1-step from index 19
# result: 6.62265915183165		process: 20/229
# Updating the model...
# Forecasting 1-step from index 20
# result: 3.1921909462724023		process: 21/229
# Updating the model...
# Forecasting 1-step from index 21
# result: 8.201275722556739		process: 22/229
# Updating the model...
# Forecasting 1-step from index 22
# result: 6.772441005418585		process: 23/229
# Updating the model...
# Forecasting 1-step from index 23
# result: 3.96091967269638		process: 24/229
# Updating the model...
# Forecasting 1-step from index 24
# result: 3.4832891941355113		process: 25/229
# Updating the model...
# Forecasting 1-step from index 25
# result: 1.6699212031067925		process: 26/229
# Updating the model...
# Forecasting 1-step from index 26
# result: 4.11481651818157		process: 27/229
# Updating the model...
# Forecasting 1-step from index 27
# result: 5.4857249915878015		process: 28/229
# Updating the model...
# Forecasting 1-step from index 28
# result: 4.312985339095368		process: 29/229
# Updating the model...
# Forecasting 1-step from index 29
# result: 2.607875606322784		process: 30/229
# Updating the model...
# Forecasting 1-step from index 30
# result: 2.404934168173551		process: 31/229
# Updating the model...
# Forecasting 1-step from index 31
# result: 4.71288531229047		process: 32/229
# Updating the model...
# Forecasting 1-step from index 32
# result: 6.48174536198339		process: 33/229
# Updating the model...
# Forecasting 1-step from index 33
# result: 3.9869279618252733		process: 34/229
# Updating the model...
# Forecasting 1-step from index 34
# result: 2.271058195422343		process: 35/229
# Updating the model...
# Forecasting 1-step from index 35
# result: 1.8567840268502438		process: 36/229
# Updating the model...
# Forecasting 1-step from index 36
# result: 2.4242859044984146		process: 37/229
# Updating the model...
# Forecasting 1-step from index 37
# result: 4.842583107591883		process: 38/229
# Updating the model...
# Forecasting 1-step from index 38
# result: 2.859124860014703		process: 39/229
# Updating the model...
# Forecasting 1-step from index 39
# result: 2.7799784851644502		process: 40/229
# Updating the model...
# Forecasting 1-step from index 40
# result: 3.3389343162979213		process: 41/229
# Updating the model...
# Forecasting 1-step from index 41
# result: 2.6876037997259443		process: 42/229
# Updating the model...
# Forecasting 1-step from index 42
# result: 4.8684119181646075		process: 43/229
# Updating the model...
# Forecasting 1-step from index 43
# result: 2.7615030836749437		process: 44/229
# Updating the model...
# Forecasting 1-step from index 44
# result: 7.879654737838408		process: 45/229
# Updating the model...
# Forecasting 1-step from index 45
# result: 3.334745869649626		process: 46/229
# Updating the model...
# Forecasting 1-step from index 46
# result: 5.696245092500547		process: 47/229
# Updating the model...
# Forecasting 1-step from index 47
# result: 6.816569500445009		process: 48/229
# Updating the model...
# Forecasting 1-step from index 48
# result: 6.852284347962283		process: 49/229
# Updating the model...
# Forecasting 1-step from index 49
# result: 4.496857728933229		process: 50/229
# Updating the model...
# Forecasting 1-step from index 50
# result: 1.339209995106186		process: 51/229
# Updating the model...
# Forecasting 1-step from index 51
# result: 2.6608929455452257		process: 52/229
# Updating the model...
# Forecasting 1-step from index 52
# result: 2.5604904145139553		process: 53/229
# Updating the model...
# Forecasting 1-step from index 53
# result: 7.727577425866912		process: 54/229
# Updating the model...
# Forecasting 1-step from index 54
# result: 5.144217461541179		process: 55/229
# Updating the model...
# Forecasting 1-step from index 55
# result: 5.231647452870063		process: 56/229
# Updating the model...
# Forecasting 1-step from index 56
# result: 4.667641768719153		process: 57/229
# Updating the model...
# Forecasting 1-step from index 57
# result: 4.407832497141371		process: 58/229
# Updating the model...
# Forecasting 1-step from index 58
# result: 3.5614246120661863		process: 59/229
# Updating the model...
# Forecasting 1-step from index 59
# result: 6.976421811940045		process: 60/229
# Updating the model...
# Forecasting 1-step from index 60
# result: 2.9547192711430212		process: 61/229
# Updating the model...
# Forecasting 1-step from index 61
# result: 2.6787582733662085		process: 62/229
# Updating the model...
# Forecasting 1-step from index 62
# result: 4.561297981444245		process: 63/229
# Updating the model...
# Forecasting 1-step from index 63
# result: 6.391922879952941		process: 64/229
# Updating the model...
# Forecasting 1-step from index 64
# result: 4.491572766337273		process: 65/229
# Updating the model...
# Forecasting 1-step from index 65
# result: 5.0126948263409545		process: 66/229
# Updating the model...
# Forecasting 1-step from index 66
# result: 4.583098880063879		process: 67/229
# Updating the model...
# Forecasting 1-step from index 67
# result: 5.722768730034236		process: 68/229
# Updating the model...
# Forecasting 1-step from index 68
# result: 6.657597746763998		process: 69/229
# Updating the model...
# Forecasting 1-step from index 69
# result: 5.280575584074805		process: 70/229
# Updating the model...
# Forecasting 1-step from index 70
# result: 3.9910286624006446		process: 71/229
# Updating the model...
# Forecasting 1-step from index 71
# result: 4.624107864234289		process: 72/229
# Updating the model...
# Forecasting 1-step from index 72
# result: 2.6881852090365337		process: 73/229
# Updating the model...
# Forecasting 1-step from index 73
# result: 5.685060912628332		process: 74/229
# Updating the model...
# Forecasting 1-step from index 74
# result: 6.374767886140971		process: 75/229
# Updating the model...
# Forecasting 1-step from index 75
# result: 4.190422043118945		process: 76/229
# Updating the model...
# Forecasting 1-step from index 76
# result: 5.055563787598921		process: 77/229
# Updating the model...
# Forecasting 1-step from index 77
# result: 6.822062952999348		process: 78/229
# Updating the model...
# Forecasting 1-step from index 78
# result: 5.518186792199965		process: 79/229
# Updating the model...
# Forecasting 1-step from index 79
# result: 4.755500700567435		process: 80/229
# Updating the model...
# Forecasting 1-step from index 80
# result: 6.16128014870425		process: 81/229
# Updating the model...
# Forecasting 1-step from index 81
# result: 1.7344887949021799		process: 82/229
# Updating the model...
# Forecasting 1-step from index 82
# result: 5.669880764823042		process: 83/229
# Updating the model...
# Forecasting 1-step from index 83
# result: 6.533974698637495		process: 84/229
# Updating the model...
# Forecasting 1-step from index 84
# result: 3.2039285684613414		process: 85/229
# Updating the model...
# Forecasting 1-step from index 85
# result: 3.0941956419863352		process: 86/229
# Updating the model...
# Forecasting 1-step from index 86
# result: 5.525349605897164		process: 87/229
# Updating the model...
# Forecasting 1-step from index 87
# result: 3.846759310640229		process: 88/229
# Updating the model...
# Forecasting 1-step from index 88
# result: 5.839777881643869		process: 89/229
# Updating the model...
# Forecasting 1-step from index 89
# result: 6.275549128941601		process: 90/229
# Updating the model...
# Forecasting 1-step from index 90
# result: 5.385722968756934		process: 91/229
# Updating the model...
# Forecasting 1-step from index 91
# result: 6.937350042297453		process: 92/229
# Updating the model...
# Forecasting 1-step from index 92
# result: 3.7060803085822296		process: 93/229
# Updating the model...
# Forecasting 1-step from index 93
# result: 3.7591121244734143		process: 94/229
# Updating the model...
# Forecasting 1-step from index 94
# result: 3.3721550658499266		process: 95/229
# Updating the model...
# Forecasting 1-step from index 95
# result: 6.289712667932848		process: 96/229
# Updating the model...
# Forecasting 1-step from index 96
# result: 3.4800602590434955		process: 97/229
# Updating the model...
# Forecasting 1-step from index 97
# result: 3.7718426137522205		process: 98/229
# Updating the model...
# Forecasting 1-step from index 98
# result: 5.3908297467079676		process: 99/229
# Updating the model...
# Forecasting 1-step from index 99
# result: 5.212149011811741		process: 100/229
# Updating the model...
# Forecasting 1-step from index 100
# result: 3.6331981620145246		process: 101/229
# Updating the model...
# Forecasting 1-step from index 101
# result: 3.4815304282605832		process: 102/229
# Updating the model...
# Forecasting 1-step from index 102
# result: 3.352549046122629		process: 103/229
# Updating the model...
# Forecasting 1-step from index 103
# result: 2.8417804535850584		process: 104/229
# Updating the model...
# Forecasting 1-step from index 104
# result: 3.243242372017863		process: 105/229
# Updating the model...
# Forecasting 1-step from index 105
# result: 5.649857084278064		process: 106/229
# Updating the model...
# Forecasting 1-step from index 106
# result: 4.123453324099984		process: 107/229
# Updating the model...
# Forecasting 1-step from index 107
# result: 1.4371839151999883		process: 108/229
# Updating the model...
# Forecasting 1-step from index 108
# result: 3.3498097857735534		process: 109/229
# Updating the model...
# Forecasting 1-step from index 109
# result: 1.6631959111766714		process: 110/229
# Updating the model...
# Forecasting 1-step from index 110
# result: 3.444998111998739		process: 111/229
# Updating the model...
# Forecasting 1-step from index 111
# result: 4.457151623416798		process: 112/229
# Updating the model...
# Forecasting 1-step from index 112
# result: 6.30928842473673		process: 113/229
# Updating the model...
# Forecasting 1-step from index 113
# result: 3.713446543883943		process: 114/229
# Updating the model...
# Forecasting 1-step from index 114
# result: 2.8996782751857175		process: 115/229
# Updating the model...
# Forecasting 1-step from index 115
# result: 6.06695063320151		process: 116/229
# Updating the model...
# Forecasting 1-step from index 116
# result: 2.4540918828652494		process: 117/229
# Updating the model...
# Forecasting 1-step from index 117
# result: 1.0479211408712268		process: 118/229
# Updating the model...
# Forecasting 1-step from index 118
# result: 5.916489322122183		process: 119/229
# Updating the model...
# Forecasting 1-step from index 119
# result: 6.13915352911316		process: 120/229
# Updating the model...
# Forecasting 1-step from index 120
# result: 4.701563691444685		process: 121/229
# Updating the model...
# Forecasting 1-step from index 121
# result: 2.7775979385220437		process: 122/229
# Updating the model...
# Forecasting 1-step from index 122
# result: 3.8115426214274306		process: 123/229
# Updating the model...
# Forecasting 1-step from index 123
# result: 5.971380226126038		process: 124/229
# Updating the model...
# Forecasting 1-step from index 124
# result: 2.5907667898115085		process: 125/229
# Updating the model...
# Forecasting 1-step from index 125
# result: 5.553481501526008		process: 126/229
# Updating the model...
# Forecasting 1-step from index 126
# result: 2.192041979322462		process: 127/229
# Updating the model...
# Forecasting 1-step from index 127
# result: 4.477633018330281		process: 128/229
# Updating the model...
# Forecasting 1-step from index 128
# result: 1.3713859396532326		process: 129/229
# Updating the model...
# Forecasting 1-step from index 129
# result: 0.9097193147640952		process: 130/229
# Updating the model...
# Forecasting 1-step from index 130
# result: 2.5041577301594495		process: 131/229
# Updating the model...
# Forecasting 1-step from index 131
# result: 6.223124710295911		process: 132/229
# Updating the model...
# Forecasting 1-step from index 132
# result: 1.1841632635965367		process: 133/229
# Updating the model...
# Forecasting 1-step from index 133
# result: 3.719904421270588		process: 134/229
# Updating the model...
# Forecasting 1-step from index 134
# result: 1.5614599895055243		process: 135/229
# Updating the model...
# Forecasting 1-step from index 135
# result: 2.7636673301431998		process: 136/229
# Updating the model...
# Forecasting 1-step from index 136
# result: 1.4153004309988875		process: 137/229
# Updating the model...
# Forecasting 1-step from index 137
# result: 3.3265022211448536		process: 138/229
# Updating the model...
# Forecasting 1-step from index 138
# result: 4.824810373789967		process: 139/229
# Updating the model...
# Forecasting 1-step from index 139
# result: 4.150878493755434		process: 140/229
# Updating the model...
# Forecasting 1-step from index 140
# result: 1.9969655904048396		process: 141/229
# Updating the model...
# Forecasting 1-step from index 141
# result: 2.65820352031355		process: 142/229
# Updating the model...
# Forecasting 1-step from index 142
# result: 0.7075923438349276		process: 143/229
# Updating the model...
# Forecasting 1-step from index 143
# result: 0.18049492729351124		process: 144/229
# Updating the model...
# Forecasting 1-step from index 144
# result: 5.038750403498098		process: 145/229
# Updating the model...
# Forecasting 1-step from index 145
# result: 2.3229535997558957		process: 146/229
# Updating the model...
# Forecasting 1-step from index 146
# result: -0.5780306068486238		process: 147/229
# Updating the model...
# Forecasting 1-step from index 147
# result: 2.7958386549059373		process: 148/229
# Updating the model...
# Forecasting 1-step from index 148
# result: 4.553196709435802		process: 149/229
# Updating the model...
# Forecasting 1-step from index 149
# result: 5.378726913971343		process: 150/229
# Updating the model...
# Forecasting 1-step from index 150
# result: 3.8605175155389775		process: 151/229
# Updating the model...
# Forecasting 1-step from index 151
# result: 2.087245287299273		process: 152/229
# Updating the model...
# Forecasting 1-step from index 152
# result: 2.622812965737314		process: 153/229
# Updating the model...
# Forecasting 1-step from index 153
# result: 4.872446520451241		process: 154/229
# Updating the model...
# Forecasting 1-step from index 154
# result: 2.440325144156948		process: 155/229
# Updating the model...
# Forecasting 1-step from index 155
# result: 1.4092310954102172		process: 156/229
# Updating the model...
# Forecasting 1-step from index 156
# result: 4.328888946408778		process: 157/229
# Updating the model...
# Forecasting 1-step from index 157
# result: 3.434356796200879		process: 158/229
# Updating the model...
# Forecasting 1-step from index 158
# result: 5.983287803062419		process: 159/229
# Updating the model...
# Forecasting 1-step from index 159
# result: 2.320604820759982		process: 160/229
# Updating the model...
# Forecasting 1-step from index 160
# result: 0.9847182260693825		process: 161/229
# Updating the model...
# Forecasting 1-step from index 161
# result: 2.699259627022912		process: 162/229
# Updating the model...
# Forecasting 1-step from index 162
# result: 0.910583672908541		process: 163/229
# Updating the model...
# Forecasting 1-step from index 163
# result: 3.252208695173075		process: 164/229
# Updating the model...
# Forecasting 1-step from index 164
# result: 3.9997969708973025		process: 165/229
# Updating the model...
# Forecasting 1-step from index 165
# result: 3.7254336337513028		process: 166/229
# Updating the model...
# Forecasting 1-step from index 166
# result: 5.862686171470716		process: 167/229
# Updating the model...
# Forecasting 1-step from index 167
# result: 4.313622591349471		process: 168/229
# Updating the model...
# Forecasting 1-step from index 168
# result: 5.160644163901213		process: 169/229
# Updating the model...
# Forecasting 1-step from index 169
# result: 4.131411883403213		process: 170/229
# Updating the model...
# Forecasting 1-step from index 170
# result: 3.278020690419995		process: 171/229
# Updating the model...
# Forecasting 1-step from index 171
# result: 3.5496688146287547		process: 172/229
# Updating the model...
# Forecasting 1-step from index 172
# result: 3.760173882942726		process: 173/229
# Updating the model...
# Forecasting 1-step from index 173
# result: 3.587145668664313		process: 174/229
# Updating the model...
# Forecasting 1-step from index 174
# result: 3.8684717680682414		process: 175/229
# Updating the model...
# Forecasting 1-step from index 175
# result: 1.5183153154236462		process: 176/229
# Updating the model...
# Forecasting 1-step from index 176
# result: 5.249405680446392		process: 177/229
# Updating the model...
# Forecasting 1-step from index 177
# result: 4.6586936879726935		process: 178/229
# Updating the model...
# Forecasting 1-step from index 178
# result: 4.43413091447233		process: 179/229
# Updating the model...
# Forecasting 1-step from index 179
# result: 4.759844563839528		process: 180/229
# Updating the model...
# Forecasting 1-step from index 180
# result: 2.71683639269098		process: 181/229
# Updating the model...
# Forecasting 1-step from index 181
# result: 4.45803525762024		process: 182/229
# Updating the model...
# Forecasting 1-step from index 182
# result: 4.289074267361558		process: 183/229
# Updating the model...
# Forecasting 1-step from index 183
# result: 4.5455004400413035		process: 184/229
# Updating the model...
# Forecasting 1-step from index 184
# result: 3.068613399824595		process: 185/229
# Updating the model...
# Forecasting 1-step from index 185
# result: 4.179075261670565		process: 186/229
# Updating the model...
# Forecasting 1-step from index 186
# result: 4.6268263100411025		process: 187/229
# Updating the model...
# Forecasting 1-step from index 187
# result: 5.2110882433255865		process: 188/229
# Updating the model...
# Forecasting 1-step from index 188
# result: 1.5195250607054838		process: 189/229
# Updating the model...
# Forecasting 1-step from index 189
# result: 3.528003500240642		process: 190/229
# Updating the model...
# Forecasting 1-step from index 190
# result: 2.6411294494725452		process: 191/229
# Updating the model...
# Forecasting 1-step from index 191
# result: 2.70168274502794		process: 192/229
# Updating the model...
# Forecasting 1-step from index 192
# result: 2.6070046887962692		process: 193/229
# Updating the model...
# Forecasting 1-step from index 193
# result: 0.8837075192455899		process: 194/229
# Updating the model...
# Forecasting 1-step from index 194
# result: 5.569531935014444		process: 195/229
# Updating the model...
# Forecasting 1-step from index 195
# result: 5.696318969885058		process: 196/229
# Updating the model...
# Forecasting 1-step from index 196
# result: 3.426777105356102		process: 197/229
# Updating the model...
# Forecasting 1-step from index 197
# result: 5.7965895780728705		process: 198/229
# Updating the model...
# Forecasting 1-step from index 198
# result: 5.194680047185072		process: 199/229
# Updating the model...
# Forecasting 1-step from index 199
# result: -0.20754599896076487		process: 200/229
# Updating the model...
# Forecasting 1-step from index 200
# result: 3.8523487854665452		process: 201/229
# Updating the model...
# Forecasting 1-step from index 201
# result: 5.278685095982977		process: 202/229
# Updating the model...
# Forecasting 1-step from index 202
# result: 2.12429897649154		process: 203/229
# Updating the model...
# Forecasting 1-step from index 203
# result: 1.995962425506892		process: 204/229
# Updating the model...
# Forecasting 1-step from index 204
# result: 2.8556116003764753		process: 205/229
# Updating the model...
# Forecasting 1-step from index 205
# result: 2.987797345284305		process: 206/229
# Updating the model...
# Forecasting 1-step from index 206
# result: 3.2812059111396206		process: 207/229
# Updating the model...
# Forecasting 1-step from index 207
# result: 2.144979414469281		process: 208/229
# Updating the model...
# Forecasting 1-step from index 208
# result: 4.092750735901738		process: 209/229
# Updating the model...
# Forecasting 1-step from index 209
# result: 3.5612822434498836		process: 210/229
# Updating the model...
# Forecasting 1-step from index 210
# result: 2.362868668496784		process: 211/229
# Updating the model...
# Forecasting 1-step from index 211
# result: 4.222095259121079		process: 212/229
# Updating the model...
# Forecasting 1-step from index 212
# result: 4.437503740996194		process: 213/229
# Updating the model...
# Forecasting 1-step from index 213
# result: 5.817950761679643		process: 214/229
# Updating the model...
# Forecasting 1-step from index 214
# result: 4.931390186551978		process: 215/229
# Updating the model...
# Forecasting 1-step from index 215
# result: 3.959278119293928		process: 216/229
# Updating the model...
# Forecasting 1-step from index 216
# result: 3.2884903567073582		process: 217/229
# Updating the model...
# Forecasting 1-step from index 217
# result: 1.168628333312653		process: 218/229
# Updating the model...
# Forecasting 1-step from index 218
# result: 4.390457270237006		process: 219/229
# Updating the model...
# Forecasting 1-step from index 219
# result: 2.549055462534096		process: 220/229
# Updating the model...
# Forecasting 1-step from index 220
# result: 2.888679886889526		process: 221/229
# Updating the model...
# Forecasting 1-step from index 221
# result: 0.747011811800744		process: 222/229
# Updating the model...
# Forecasting 1-step from index 222
# result: 2.98283618902662		process: 223/229
# Updating the model...
# Forecasting 1-step from index 223
# result: 2.5293835045761135		process: 224/229
# Updating the model...
# Forecasting 1-step from index 224
# result: 1.5348494385513167		process: 225/229
# Updating the model...
# Forecasting 1-step from index 225
# result: 1.6616537623769405		process: 226/229
# Updating the model...
# Forecasting 1-step from index 226
# result: 4.084694465890785		process: 227/229
# Updating the model...
# Forecasting 1-step from index 227
# result: 4.154471675536751		process: 228/229
# Updating the model...
# Forecasting 1-step from index 228
# result: 2.0615372854694964		process: 229/229
# Updating the model...
# Wall time: 2h 1min 33s

# %%
sc1_forecast_df, __, __ = execute_forecast(sc1_forecast, dtest)
# Out:
# Mean Absolute Error is		: 2.4334455873743974
# Root Mean Squared Error is	: 2.917736616515964

# %% [markdown]
# ### Forecast scenario 2 : 3 time step

# %%
# %%time
sc2_forecast = period_forecast(model_loc, 3, dtest, test_exg)
# Out:
# Forecasting 3-step from index 0
# result: 6.701558472959658		process: 1/229
# result: 5.507517286760546		process: 2/229
# result: 4.486808646879733		process: 3/229
# Updating the model...
# Forecasting 3-step from index 3
# result: 7.573976404545821		process: 4/229
# result: 6.901650620575699		process: 5/229
# result: 8.191502932635554		process: 6/229
# Updating the model...
# Forecasting 3-step from index 6
# result: 6.3003965790091865		process: 7/229
# result: 7.0894777815302525		process: 8/229
# result: 6.596696983017822		process: 9/229
# Updating the model...
# Forecasting 3-step from index 9
# result: 4.772582176373799		process: 10/229
# result: 6.475828262036956		process: 11/229
# result: 4.851072123282991		process: 12/229
# Updating the model...
# Forecasting 3-step from index 12
# result: 4.200142571568259		process: 13/229
# result: 6.616444681746897		process: 14/229
# result: 6.387999575322061		process: 15/229
# Updating the model...
# Forecasting 3-step from index 15
# result: 3.8257060053277927		process: 16/229
# result: 5.081517689948401		process: 17/229
# result: 5.249657674681128		process: 18/229
# Updating the model...
# Forecasting 3-step from index 18
# result: 8.10413768988724		process: 19/229
# result: 6.657260005812585		process: 20/229
# result: 4.7153180856182715		process: 21/229
# Updating the model...
# Forecasting 3-step from index 21
# result: 8.226778710306888		process: 22/229
# result: 7.762892297672118		process: 23/229
# result: 6.092493556305168		process: 24/229
# Updating the model...
# Forecasting 3-step from index 24
# result: 3.588519535138828		process: 25/229
# result: 1.9030832074916246		process: 26/229
# result: 3.5087897360091413		process: 27/229
# Updating the model...
# Forecasting 3-step from index 27
# result: 5.550933867006344		process: 28/229
# result: 4.063398179687877		process: 29/229
# result: 3.635065912782148		process: 30/229
# Updating the model...
# Forecasting 3-step from index 30
# result: 2.4734782218011477		process: 31/229
# result: 3.585170909672628		process: 32/229
# result: 5.2413488195464515		process: 33/229
# Updating the model...
# Forecasting 3-step from index 33
# result: 4.01357813885861		process: 34/229
# result: 3.7077522792871003		process: 35/229
# result: 3.421516581623539		process: 36/229
# Updating the model...
# Forecasting 3-step from index 36
# result: 2.5261026971006446		process: 37/229
# result: 3.6698910715250004		process: 38/229
# result: 2.6795460103708013		process: 39/229
# Updating the model...
# Forecasting 3-step from index 39
# result: 2.7773185227148787		process: 40/229
# result: 4.339529660306504		process: 41/229
# result: 3.266171221649709		process: 42/229
# Updating the model...
# Forecasting 3-step from index 42
# result: 4.8767597594293886		process: 43/229
# result: 3.1250590506533453		process: 44/229
# result: 6.3322158716695585		process: 45/229
# Updating the model...
# Forecasting 3-step from index 45
# result: 3.311745770981748		process: 46/229
# result: 4.621102729101815		process: 47/229
# result: 5.3489594019314985		process: 48/229
# Updating the model...
# Forecasting 3-step from index 48
# result: 6.8008302191873735		process: 49/229
# result: 5.039736539917505		process: 50/229
# result: 2.8246254555556547		process: 51/229
# Updating the model...
# Forecasting 3-step from index 51
# result: 2.6922335113936304		process: 52/229
# result: 2.863971036770078		process: 53/229
# result: 5.823389544890206		process: 54/229
# Updating the model...
# Forecasting 3-step from index 54
# result: 5.090732198557739		process: 55/229
# result: 3.995108469986901		process: 56/229
# result: 3.314277239870316		process: 57/229
# Updating the model...
# Forecasting 3-step from index 57
# result: 4.348824479234015		process: 58/229
# result: 3.454977354399099		process: 59/229
# result: 5.974401944808684		process: 60/229
# Updating the model...
# Forecasting 3-step from index 60
# result: 2.931170848376289		process: 61/229
# result: 2.2444126987610673		process: 62/229
# result: 2.6396659307401533		process: 63/229
# Updating the model...
# Forecasting 3-step from index 63
# result: 6.3391457131835205		process: 64/229
# result: 4.929606913738124		process: 65/229
# result: 3.4878198992545877		process: 66/229
# Updating the model...
# Forecasting 3-step from index 66
# result: 4.508247818524631		process: 67/229
# result: 4.707377716824998		process: 68/229
# result: 4.909867010199266		process: 69/229
# Updating the model...
# Forecasting 3-step from index 69
# result: 5.218143404814121		process: 70/229
# result: 4.018286729961624		process: 71/229
# result: 5.34478996793898		process: 72/229
# Updating the model...
# Forecasting 3-step from index 72
# result: 2.7053057859836986		process: 73/229
# result: 4.032255283308962		process: 74/229
# result: 4.954218939733105		process: 75/229
# Updating the model...
# Forecasting 3-step from index 75
# result: 4.137653827979166		process: 76/229
# result: 3.8043140058807468		process: 77/229
# result: 5.7198118148143		process: 78/229
# Updating the model...
# Forecasting 3-step from index 78
# result: 5.493436582894376		process: 79/229
# result: 6.649473778510824		process: 80/229
# result: 6.277689339302897		process: 81/229
# Updating the model...
# Forecasting 3-step from index 81
# result: 1.7593146223619578		process: 82/229
# result: 4.465978320809523		process: 83/229
# result: 4.680562170251861		process: 84/229
# Updating the model...
# Forecasting 3-step from index 84
# result: 3.1548247356565513		process: 85/229
# result: 3.494267110078729		process: 86/229
# result: 4.982712469933767		process: 87/229
# Updating the model...
# Forecasting 3-step from index 87
# result: 3.8455163082085253		process: 88/229
# result: 5.059407510246661		process: 89/229
# result: 5.48895210047307		process: 90/229
# Updating the model...
# Forecasting 3-step from index 90
# result: 5.372115255457936		process: 91/229
# result: 6.982869819325256		process: 92/229
# result: 5.062558705377149		process: 93/229
# Updating the model...
# Forecasting 3-step from index 93
# result: 3.834174792592132		process: 94/229
# result: 3.4405068107688948		process: 95/229
# result: 5.169139805753894		process: 96/229
# Updating the model...
# Forecasting 3-step from index 96
# result: 3.4795157035105095		process: 97/229
# result: 3.8213782329492236		process: 98/229
# result: 4.498408664090917		process: 99/229
# Updating the model...
# Forecasting 3-step from index 99
# result: 5.188857838710811		process: 100/229
# result: 4.97860685852186		process: 101/229
# result: 4.662191593920695		process: 102/229
# Updating the model...
# Forecasting 3-step from index 102
# result: 3.3832186859684787		process: 103/229
# result: 2.9233281450345654		process: 104/229
# result: 4.285950078948027		process: 105/229
# Updating the model...
# Forecasting 3-step from index 105
# result: 5.688795477067388		process: 106/229
# result: 5.265461265186825		process: 107/229
# result: 2.618878511873489		process: 108/229
# Updating the model...
# Forecasting 3-step from index 108
# result: 3.3730482924886758		process: 109/229
# result: 2.7894368301204437		process: 110/229
# result: 4.355362420127296		process: 111/229
# Updating the model...
# Forecasting 3-step from index 111
# result: 4.502088437431894		process: 112/229
# result: 5.5309813376040715		process: 113/229
# result: 4.672800428894616		process: 114/229
# Updating the model...
# Forecasting 3-step from index 114
# result: 2.9845811461416143		process: 115/229
# result: 4.411828742412656		process: 116/229
# result: 2.954165264627456		process: 117/229
# Updating the model...
# Forecasting 3-step from index 117
# result: 1.0834580805566145		process: 118/229
# result: 4.730982636157163		process: 119/229
# result: 4.744805373847513		process: 120/229
# Updating the model...
# Forecasting 3-step from index 120
# result: 4.6554783799199875		process: 121/229
# result: 3.00595856965806		process: 122/229
# result: 3.2940874393438278		process: 123/229
# Updating the model...
# Forecasting 3-step from index 123
# result: 5.976618814929699		process: 124/229
# result: 3.434410613555678		process: 125/229
# result: 4.302659789601243		process: 126/229
# Updating the model...
# Forecasting 3-step from index 126
# result: 2.171807980256425		process: 127/229
# result: 4.242280949851298		process: 128/229
# result: 2.780583145166098		process: 129/229
# Updating the model...
# Forecasting 3-step from index 129
# result: 0.9495038686193715		process: 130/229
# result: 2.8670548192669676		process: 131/229
# result: 5.9257311311144605		process: 132/229
# Updating the model...
# Forecasting 3-step from index 132
# result: 1.2199194767524137		process: 133/229
# result: 2.021306884705991		process: 134/229
# result: 1.6695631170902034		process: 135/229
# Updating the model...
# Forecasting 3-step from index 135
# result: 2.821678239450835		process: 136/229
# result: 2.3983696607614804		process: 137/229
# result: 4.3881299474745195		process: 138/229
# Updating the model...
# Forecasting 3-step from index 138
# result: 4.8534260667175495		process: 139/229
# result: 5.255182154768967		process: 140/229
# result: 4.0840595487628715		process: 141/229
# Updating the model...
# Forecasting 3-step from index 141
# result: 2.7265786118981854		process: 142/229
# result: 1.6756901186690043		process: 143/229
# result: 0.6781983344336924		process: 144/229
# Updating the model...
# Forecasting 3-step from index 144
# result: 5.0537931426642775		process: 145/229
# result: 4.037560746344583		process: 146/229
# result: 1.241005360400238		process: 147/229
# Updating the model...
# Forecasting 3-step from index 147
# result: 2.855433916656679		process: 148/229
# result: 3.30367774281532		process: 149/229
# result: 4.001306682286027		process: 150/229
# Updating the model...
# Forecasting 3-step from index 150
# result: 3.819704564470956		process: 151/229
# result: 1.8073657650881243		process: 152/229
# result: 1.936082844156791		process: 153/229
# Updating the model...
# Forecasting 3-step from index 153
# result: 4.859174370578369		process: 154/229
# result: 2.4955205753346714		process: 155/229
# result: 2.2605264085425607		process: 156/229
# Updating the model...
# Forecasting 3-step from index 156
# result: 4.330818550973551		process: 157/229
# result: 4.361064515083496		process: 158/229
# result: 6.6757110600328815		process: 159/229
# Updating the model...
# Forecasting 3-step from index 159
# result: 2.316492158439358		process: 160/229
# result: 1.7935864738010616		process: 161/229
# result: 3.492627188840331		process: 162/229
# Updating the model...
# Forecasting 3-step from index 162
# result: 0.965753011061321		process: 163/229
# result: 1.7508387951582987		process: 164/229
# result: 2.1772126324073913		process: 165/229
# Updating the model...
# Forecasting 3-step from index 165
# result: 3.6646904484056515		process: 166/229
# result: 4.914237380591296		process: 167/229
# result: 4.212234756542982		process: 168/229
# Updating the model...
# Forecasting 3-step from index 168
# result: 5.144118090530044		process: 169/229
# result: 5.234557459811592		process: 170/229
# result: 3.159042829083683		process: 171/229
# Updating the model...
# Forecasting 3-step from index 171
# result: 3.540928558696649		process: 172/229
# result: 3.3301549725061084		process: 173/229
# result: 3.8201925519129762		process: 174/229
# Updating the model...
# Forecasting 3-step from index 174
# result: 3.8627410538895353		process: 175/229
# result: 2.7616722548231785		process: 176/229
# result: 3.771346967382973		process: 177/229
# Updating the model...
# Forecasting 3-step from index 177
# result: 4.615684880408926		process: 178/229
# result: 4.013132386737852		process: 179/229
# result: 4.204093179513774		process: 180/229
# Updating the model...
# Forecasting 3-step from index 180
# result: 2.713524625033495		process: 181/229
# result: 3.397160036592629		process: 182/229
# result: 3.0406037176780134		process: 183/229
# Updating the model...
# Forecasting 3-step from index 183
# result: 4.523726352625452		process: 184/229
# result: 4.607622307105626		process: 185/229
# result: 4.501221411194056		process: 186/229
# Updating the model...
# Forecasting 3-step from index 186
# result: 4.634657634127759		process: 187/229
# result: 4.964111766339952		process: 188/229
# result: 3.1105596821911257		process: 189/229
# Updating the model...
# Forecasting 3-step from index 189
# result: 3.562110616354491		process: 190/229
# result: 3.766575334230512		process: 191/229
# result: 4.316434773297615		process: 192/229
# Updating the model...
# Forecasting 3-step from index 192
# result: 2.6147161381072066		process: 193/229
# result: 1.8466111561637018		process: 194/229
# result: 3.8635832714585203		process: 195/229
# Updating the model...
# Forecasting 3-step from index 195
# result: 5.638289206042342		process: 196/229
# result: 5.278981881661635		process: 197/229
# result: 6.209294740164259		process: 198/229
# Updating the model...
# Forecasting 3-step from index 198
# result: 5.18536414212643		process: 199/229
# result: 1.4555984554863923		process: 200/229
# result: 2.318548742348131		process: 201/229
# Updating the model...
# Forecasting 3-step from index 201
# result: 5.246286022587347		process: 202/229
# result: 3.5863978890649975		process: 203/229
# result: 2.7214053019081934		process: 204/229
# Updating the model...
# Forecasting 3-step from index 204
# result: 2.8421567627892577		process: 205/229
# result: 2.9457676795876804		process: 206/229
# result: 3.6752443142774474		process: 207/229
# Updating the model...
# Forecasting 3-step from index 207
# result: 2.1224825944975634		process: 208/229
# result: 2.5418119251483797		process: 209/229
# result: 2.156177037340478		process: 210/229
# Updating the model...
# Forecasting 3-step from index 210
# result: 2.310276857141959		process: 211/229
# result: 3.3667834323608616		process: 212/229
# result: 4.760170147963216		process: 213/229
# Updating the model...
# Forecasting 3-step from index 213
# result: 5.801301854728745		process: 214/229
# result: 5.5731846277755945		process: 215/229
# result: 4.616097370351124		process: 216/229
# Updating the model...
# Forecasting 3-step from index 216
# result: 3.3536640456360516		process: 217/229
# result: 0.8809883125794535		process: 218/229
# result: 2.777920290531499		process: 219/229
# Updating the model...
# Forecasting 3-step from index 219
# result: 2.539973041065017		process: 220/229
# result: 3.656786629372416		process: 221/229
# result: 1.1531174145957044		process: 222/229
# Updating the model...
# Forecasting 3-step from index 222
# result: 2.9867973016018943		process: 223/229
# result: 2.063925183156452		process: 224/229
# result: 2.099879663856683		process: 225/229
# Updating the model...
# Forecasting 3-step from index 225
# result: 1.6567648107592874		process: 226/229
# result: 2.1097846684477		process: 227/229
# result: 2.2601435953299696		process: 228/229
# Updating the model...
# Forecasting 1-step from index 228
# result: 1.997151633206029		process: 229/229
# Updating the model...
# Wall time: 40min 30s

# %%
sc2_forecast_df, __, __ = execute_forecast(sc2_forecast, dtest)
# Out:
# Mean Absolute Error is		: 2.533693284254814
# Root Mean Squared Error is	: 2.9874499691580425

# %% [markdown]
# ### Forecast scenario 3 : 7 time step

# %%
# %%time
sc3_forecast = period_forecast(model_loc, 7, dtest, test_exg)
# Out:
# Forecasting 7-step from index 0
# result: 6.701558472959656		process: 1/229
# result: 5.507517286760546		process: 2/229
# result: 4.486808646879734		process: 3/229
# result: 7.119855685386097		process: 4/229
# result: 6.6388497456550395		process: 5/229
# result: 8.029642301206234		process: 6/229
# result: 8.135895216287615		process: 7/229
# Updating the model...
# Forecasting 7-step from index 7
# result: 7.374186485477601		process: 8/229
# result: 6.765916738861517		process: 9/229
# result: 4.507878453357259		process: 10/229
# result: 6.353939010108414		process: 11/229
# result: 4.761516032908463		process: 213/229
# result: 6.43733860991348		process: 214/229
# result: 5.940786840981249		process: 215/229
# result: 4.8336920685423195		process: 216/229
# result: 4.980083394202002		process: 217/229
# Updating the model...
# Forecasting 7-step from index 217
# result: 1.2386218223282708		process: 218/229
# result: 2.9871982705301003		process: 219/229
# result: 3.1301446861477116		process: 220/229
# result: 3.975184222797971		process: 221/229
# result: 1.3270056444653275		process: 222/229
# result: 3.580624533860826		process: 223/229
# result: 2.425832685235026		process: 224/229
# Updating the model...
# Forecasting 5-step from index 224
# result: 1.5299265360450576		process: 225/229
# result: 1.0782914087964177		process: 226/229
# result: 1.768989308310021		process: 227/229
# result: 2.047749518713129		process: 228/229
# result: 1.2838861953460339		process: 229/229
# Updating the model...
# Wall time: 18min 4s

# %%
sc3_forecast_df, __, __ = execute_forecast(sc3_forecast, dtest)
# Out:
# Mean Absolute Error is		: 2.596808779372431
# Root Mean Squared Error is	: 3.044083721313838

# %% [markdown]
# # Collecting All Predictions Scenario Result

# %%
def plot_forecasts_result(res_df):
    title = 'Peramalan ' + ATTR_NAME + ' ARIMA'
    
    plt.figure(figsize=(18,8))
    plt.title(title)
    plt.plot(res_df['scn-1'], 'r-', label='1-step forecast')
    plt.plot(res_df['scn-2'], 'b-', label='3-step forecast')
    plt.plot(res_df['scn-3'], 'g-', label='7-step forecast')
    plt.plot(res_df['Actuals'], color='black', linestyle=':' , label='Actuals')
    plt.legend()

# %%
def col_forcasts_err(res_df):
    for col in [x for x in range(len(forecasts_result.columns)-1)]:
        col_name = res_df.columns[col]
        MAE = mean_absolute_error(res_df['Actuals'], res_df[col_name])
        RMSE = sqrt(mean_squared_error(res_df['Actuals'], res_df[col_name]))
        print('Error for ', col_name)
        print(f'Mean Absolute Error is\t\t: {MAE}')
        print(f'Root Mean Squared Error is\t: {RMSE}')
        print()

# %%
sc1_df_cp = sc1_forecast_df.copy()
sc1_df_cp.columns = ['scn-1', 'Actuals']

sc2_df_cp = sc2_forecast_df.copy()
sc2_df_cp.columns = ['scn-2', 'Actuals']

sc3_df_cp = sc3_forecast_df.copy()
sc3_df_cp.columns = ['scn-3', 'Actuals']

# %%
forecasts_result = pd.concat([sc1_df_cp[[sc1_df_cp.columns[0]]],
                              sc2_df_cp[[sc2_df_cp.columns[0]]],
                              sc3_df_cp[[sc3_df_cp.columns[0]]],
                              sc1_df_cp[[sc3_df_cp.columns[1]]]
                             ],
                               axis='columns')

# %%
plot_forecasts_result(forecasts_result)

# %%
col_forcasts_err(forecasts_result)
# Out:
# Error for  scn-1
# Mean Absolute Error is		: 2.4334455873743974
# Root Mean Squared Error is	: 2.917736616515964
#
# Error for  scn-2
# Mean Absolute Error is		: 2.533693284254814
# Root Mean Squared Error is	: 2.9874499691580425
#
# Error for  scn-3
# Mean Absolute Error is		: 2.596808779372431
# Root Mean Squared Error is	: 3.044083721313838

# %% [markdown]
# ## Saving forecasts result

# %%
forecasts_result.to_csv('ARIMA_results/'+ATTR_NOW+'.csv')
