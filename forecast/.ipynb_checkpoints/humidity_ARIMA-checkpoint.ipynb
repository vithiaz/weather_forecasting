# %%
ATTR_NOW = 'avg_humidity'

# %%
attr_dict = {
    'min_temp': ('mnt', 'Temperatur minimum'),
    'max_temp': ('mxt', 'Temperatur maksimum'),
    'avg_temp': ('avgt', 'Temperatur rata-rata'),
    'avg_humidity': ('hum', 'Kelembapan rata-rata'),
    'sunshine': ('sun', 'Penyinaran matahari'),
    'rainfall': ('rain', 'Curah hujan'),
}

ATTR_CODE = attr_dict[ATTR_NOW][0]
ATTR_NAME = attr_dict[ATTR_NOW][1]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.tsa.stattools as sts
import statsmodels.graphics.tsaplots as sgt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose

from pmdarima.arima import auto_arima, ndiffs, nsdiffs

from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

import scipy.stats as stats
from scipy.stats import boxcox
from scipy.special import inv_boxcox
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../attributes_dataset/humidity.csv')
df.date = pd.to_datetime(df.date, format='%Y-%m-%d')
df.set_index('date', inplace=True)
df.head()
# Out:
#             avg_humidity
# date
# 2018-01-01          87.5
# 2018-01-02          94.0
# 2018-01-03          94.0
# 2018-01-04          88.0
# 2018-01-05          89.0

# %% [markdown]
# # Splitting Data

# %%
train_ratio = int(len(df) * 0.9)

# %%
dtrain = df.iloc[:train_ratio]
dtest = df.iloc[train_ratio:]

# %%
print(dtrain.shape)
print(dtest.shape)
# Out:
# (1395, 1)
# (156, 1)

# %% [markdown]
# # Visualisasi ACF dan PACF

# %%
lags = 40
fig, ax = plt.subplots(1,2,figsize=(11,3))
plt.suptitle(ATTR_NAME, fontsize=14)
sgt.plot_acf(dtrain, lags=lags, zero=False, ax=ax[0])
sgt.plot_pacf(dtrain, lags=lags, zero=False, ax=ax[1])
plt.show()

# %%
plt.figure(figsize=(18,6))
plt.plot(dtrain)

# %%
plt.figure(figsize=(18,4))
plt.plot(dtrain.loc['2019-01-01':'2020-01-01'])

# %%
dtrain.head(5)
# Out:
#             avg_humidity
# date
# 2018-01-01          87.5
# 2018-01-02          94.0
# 2018-01-03          94.0
# 2018-01-04          88.0
# 2018-01-05          89.0

# %% [markdown]
# # Stasionary Test (dickey fuller)

# %%
adf = sts.adfuller(dtrain)
print(f'ADF p values\t\t: {adf[1]}')
print(f'ADF statistic values\t: {adf[0]}')
print(f'ADF critical values\t: {adf[4]}')
# Out:
# ADF p values		: 2.9630198681566646e-10
# ADF statistic values	: -7.161317540117949
# ADF critical values	: {'1%': -3.435080296942406, '5%': -2.863629081525758, '10%': -2.567882222497361}

# %%
# p-value < 0.05 tidak stasioner
sts.kpss(dtrain, regression='ct')
# Out:
# (0.09231442632516067,
#  0.1,
#  24,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %% [markdown]
# ### Data stasioner karena p values < 0.05 dan statistic values < 5% critical values  menurut ADF TEST

# %% [markdown]
# # Levene Test

# %%
len_dtrain = len(dtrain)
levgrp_1 = dtrain.avg_humidity.iloc[int(0.2*len_dtrain):int(0.6*len_dtrain)].values
levgrp_2 = dtrain.avg_humidity.iloc[:int(0.4*len_dtrain)].values
levgrp_3 = dtrain.avg_humidity.iloc[int(0.8*len_dtrain):].values
levgrp_4 = dtrain.avg_humidity.iloc[int(0.2*len_dtrain):int(0.9*len_dtrain)].values

# %%
#levene p-value > 0.05 == varian stasioner

levene_val = stats.levene(levgrp_1, levgrp_2, levgrp_3, levgrp_4, center='mean')
print(levene_val)
if levene_val[1] > 0.05:
    print('Varian Stasioner')
else:
    print('Varian Tidak Stasioner')
# Out:
# LeveneResult(statistic=4.075960309034287, pvalue=0.00673171288399278)
# Varian Tidak Stasioner

# %%
d_value = ndiffs(dtrain, test='kpss')
d_value
# Out:
# 0

# %% [markdown]
# ### Menurut KPSS test, yang menguji Trend Stationarity.. data sudah stasioner

# %% [markdown]
# # Boxcox Transformation

# %%
trans = boxcox(dtrain.avg_humidity)
dtrain_trans = trans[0]
trans_lambdas = trans[1]

# %%
df_dtrain_trans = dtrain.copy()
df_dtrain_trans.avg_humidity = dtrain_trans

# %% [markdown]
# # Auto Arima Model

# %%
train_exg = pd.read_csv('../R_resource/humidity_train_exog182.csv')
train_exg = train_exg.drop(columns='Unnamed: 0')

# %%
test_exg = pd.read_csv('../R_resource/humidity_test_exog182.csv')
test_exg = test_exg.drop(columns='Unnamed: 0')

# %%
print(train_exg.shape)
print(test_exg.shape)
# Out:
# (1395, 364)
# (156, 364)

# %% [raw]
# %%time
# model = auto_arima(df_dtrain_trans, exogenous=train_exg, trace=True, stepwise=True,
#                        max_p=7, max_q=7, d=0)

# %%
model_loc = f'ARIMA_models/{ATTR_NOW}.pkl'

# %% [raw]
# ## saving model
#
# with open(model_loc, 'wb') as pkl:
#     pickle.dump(model, pkl)

# %%
## open the model

with open(model_loc, 'rb') as pkl:
    model = pickle.load(pkl)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1395
# Model:               SARIMAX(4, 0, 6)   Log Likelihood              -28748.196
# Date:                Sat, 09 Jul 2022   AIC                          58248.393
# Time:                        17:16:00   BIC                          60218.877
# Sample:                             0   HQIC                         58985.135
#                                - 1395
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   2.271e+08   2.01e-08   1.13e+16      0.000    2.27e+08    2.27e+08
# S1-365      1.646e+08   5.88e-10    2.8e+17      0.000    1.65e+08    1.65e+08
# C1-365     -4.945e+07   1.45e-08  -3.42e+15      0.000   -4.95e+07   -4.95e+07
# S2-365      6.213e+07   8.62e-10    7.2e+16      0.000    6.21e+07    6.21e+07
# C2-365     -1.384e+07   1.55e-08  -8.91e+14      0.000   -1.38e+07   -1.38e+07
# S3-365      7.997e+07   4.06e-09   1.97e+16      0.000       8e+07       8e+07
# C3-365     -9.827e+06   1.55e-08  -6.36e+14      0.000   -9.83e+06   -9.83e+06
# S4-365      4.372e+07   1.64e-09   2.66e+16      0.000    4.37e+07    4.37e+07
# C4-365       3.96e+07   5.31e-09   7.45e+15      0.000    3.96e+07    3.96e+07
# S5-365     -1.058e+07   4.74e-09  -2.23e+15      0.000   -1.06e+07   -1.06e+07
# C5-365     -4.617e+06   5.48e-09  -8.42e+14      0.000   -4.62e+06   -4.62e+06
# S6-365     -6.358e+06   4.63e-09  -1.37e+15      0.000   -6.36e+06   -6.36e+06
# C6-365      4.145e+06   2.07e-09   2.01e+15      0.000    4.15e+06    4.15e+06
# S7-365      3.373e+07   1.03e-08   3.28e+15      0.000    3.37e+07    3.37e+07
# C7-365      -3.58e+07   4.77e-09  -7.51e+15      0.000   -3.58e+07   -3.58e+07
# S8-365      5.578e+07    1.4e-08   3.97e+15      0.000    5.58e+07    5.58e+07
# C8-365     -1.846e+07   3.78e-09  -4.89e+15      0.000   -1.85e+07   -1.85e+07
# S9-365      2.626e+07   7.63e-09   3.44e+15      0.000    2.63e+07    2.63e+07
# C9-365      2.821e+07    3.7e-09   7.63e+15      0.000    2.82e+07    2.82e+07
# S10-365     2.118e+07   1.35e-09   1.57e+16      0.000    2.12e+07    2.12e+07
# C10-365     3.505e+07   2.73e-09   1.28e+16      0.000    3.51e+07    3.51e+07
# S11-365     3.609e+06   2.46e-09   1.47e+15      0.000    3.61e+06    3.61e+06
# C11-365     3.006e+06   4.34e-10   6.92e+15      0.000    3.01e+06    3.01e+06
# S12-365     8.544e+06   2.62e-09   3.27e+15      0.000    8.54e+06    8.54e+06
# C12-365     7.922e+06    1.1e-09   7.19e+15      0.000    7.92e+06    7.92e+06
# S13-365     3.117e+07    4.4e-10   7.09e+16      0.000    3.12e+07    3.12e+07
# C13-365     2.627e+06   8.88e-09   2.96e+14      0.000    2.63e+06    2.63e+06
# S14-365     4.381e+07   4.66e-09    9.4e+15      0.000    4.38e+07    4.38e+07
# C14-365    -6.876e+06   3.45e-09  -1.99e+15      0.000   -6.88e+06   -6.88e+06
# S15-365     8.972e+05   1.02e-08   8.76e+13      0.000    8.97e+05    8.97e+05
# C15-365    -1.672e+07   8.44e-10  -1.98e+16      0.000   -1.67e+07   -1.67e+07
# S16-365      3.07e+06   3.69e-09   8.31e+14      0.000    3.07e+06    3.07e+06
# C16-365     3.396e+06   4.77e-10   7.12e+15      0.000     3.4e+06     3.4e+06
# S17-365     4.538e+06   8.95e-09   5.07e+14      0.000    4.54e+06    4.54e+06
# C17-365    -2.443e+07   2.87e-09  -8.52e+15      0.000   -2.44e+07   -2.44e+07
# S18-365      9.09e+06   2.89e-09   3.14e+15      0.000    9.09e+06    9.09e+06
# C18-365    -6.118e+06   3.99e-09  -1.53e+15      0.000   -6.12e+06   -6.12e+06
# S19-365     8.447e+06   4.21e-09   2.01e+15      0.000    8.45e+06    8.45e+06
# C19-365    -1.447e+07   6.37e-09  -2.27e+15      0.000   -1.45e+07   -1.45e+07
# S20-365     9.066e+06   1.05e-09   8.62e+15      0.000    9.07e+06    9.07e+06
# C20-365    -7.027e+06   6.48e-09  -1.09e+15      0.000   -7.03e+06   -7.03e+06
# S21-365     7.688e+06   1.59e-09   4.82e+15      0.000    7.69e+06    7.69e+06
# C21-365      6.73e+06   4.37e-10   1.54e+16      0.000    6.73e+06    6.73e+06
# S22-365    -1.134e+05   4.96e-09  -2.29e+13      0.000   -1.13e+05   -1.13e+05
# C22-365     2.176e+07   3.62e-09      6e+15      0.000    2.18e+07    2.18e+07
# S23-365    -2.551e+06    9.9e-10  -2.58e+15      0.000   -2.55e+06   -2.55e+06
# C23-365    -5.548e+06   6.74e-09  -8.23e+14      0.000   -5.55e+06   -5.55e+06
# S24-365    -1.345e+06   3.68e-09  -3.65e+14      0.000   -1.34e+06   -1.34e+06
# C24-365    -1.634e+07   7.16e-09  -2.28e+15      0.000   -1.63e+07   -1.63e+07
# S25-365     4.538e+06    1.5e-09   3.02e+15      0.000    4.54e+06    4.54e+06
# C25-365    -2.118e+07   2.81e-09  -7.53e+15      0.000   -2.12e+07   -2.12e+07
# S26-365     4.238e+05   5.87e-09   7.22e+13      0.000    4.24e+05    4.24e+05
# C26-365     8.997e+06   1.77e-09   5.09e+15      0.000       9e+06       9e+06
# S27-365     4.272e+06   1.43e-09      3e+15      0.000    4.27e+06    4.27e+06
# C27-365    -2.502e+07   6.79e-09  -3.68e+15      0.000    -2.5e+07    -2.5e+07
# S28-365     7.651e+06   6.94e-10    1.1e+16      0.000    7.65e+06    7.65e+06
# C28-365     6.447e+06   6.55e-09   9.85e+14      0.000    6.45e+06    6.45e+06
# S29-365     6.916e+06   8.92e-10   7.75e+15      0.000    6.92e+06    6.92e+06
# C29-365     1.901e+07   6.55e-09    2.9e+15      0.000     1.9e+07     1.9e+07
# S30-365     -2.61e+05   1.79e-09  -1.46e+14      0.000   -2.61e+05   -2.61e+05
# C30-365    -2.429e+07   3.53e-09  -6.88e+15      0.000   -2.43e+07   -2.43e+07
# S31-365     2.694e+07   3.82e-09   7.05e+15      0.000    2.69e+07    2.69e+07
# C31-365     -2.46e+06   9.17e-09  -2.68e+14      0.000   -2.46e+06   -2.46e+06
# S32-365     2.294e+07   6.97e-09   3.29e+15      0.000    2.29e+07    2.29e+07
# C32-365     1.681e+07   1.46e-09   1.16e+16      0.000    1.68e+07    1.68e+07
# S33-365    -2.376e+06   2.61e-09  -9.11e+14      0.000   -2.38e+06   -2.38e+06
# C33-365    -8.316e+04   1.36e-08  -6.13e+12      0.000   -8.32e+04   -8.32e+04
# S34-365     4.655e+06   4.15e-09   1.12e+15      0.000    4.65e+06    4.65e+06
# C34-365     2.432e+06   3.88e-09   6.28e+14      0.000    2.43e+06    2.43e+06
# S35-365    -1.019e+07   4.08e-09   -2.5e+15      0.000   -1.02e+07   -1.02e+07
# C35-365    -1.315e+07   6.51e-09  -2.02e+15      0.000   -1.31e+07   -1.31e+07
# S36-365    -1.204e+07   2.76e-09  -4.36e+15      0.000    -1.2e+07    -1.2e+07
# C36-365    -2.184e+07   3.07e-09  -7.11e+15      0.000   -2.18e+07   -2.18e+07
# S37-365     1.653e+07   1.24e-09   1.33e+16      0.000    1.65e+07    1.65e+07
# C37-365    -2.002e+07    2.6e-10  -7.71e+16      0.000      -2e+07      -2e+07
# S38-365     1.158e+07   4.86e-09   2.39e+15      0.000    1.16e+07    1.16e+07
# C38-365    -3.759e+06   9.48e-10  -3.96e+15      0.000   -3.76e+06   -3.76e+06
# S39-365    -1.552e+07   1.66e-09  -9.37e+15      0.000   -1.55e+07   -1.55e+07
# C39-365    -1.211e+07   5.58e-09  -2.17e+15      0.000   -1.21e+07   -1.21e+07
# S40-365     4.719e+06   2.93e-09   1.61e+15      0.000    4.72e+06    4.72e+06
# C40-365    -7.451e+05   9.78e-09  -7.62e+13      0.000   -7.45e+05   -7.45e+05
# S41-365     -5.96e+06   5.37e-09  -1.11e+15      0.000   -5.96e+06   -5.96e+06
# C41-365    -1.882e+07   9.03e-09  -2.08e+15      0.000   -1.88e+07   -1.88e+07
# S42-365     3.109e+06   3.92e-09   7.94e+14      0.000    3.11e+06    3.11e+06
# C42-365    -4.793e+06   6.77e-09  -7.08e+14      0.000   -4.79e+06   -4.79e+06
# S43-365     6.712e+06   1.79e-09   3.76e+15      0.000    6.71e+06    6.71e+06
# C43-365    -9.571e+06   3.09e-09   -3.1e+15      0.000   -9.57e+06   -9.57e+06
# S44-365    -3.858e+06   5.99e-09  -6.44e+14      0.000   -3.86e+06   -3.86e+06
# C44-365    -8.729e+06   1.38e-09  -6.35e+15      0.000   -8.73e+06   -8.73e+06
# S45-365     9.375e+06   1.51e-10   6.19e+16      0.000    9.37e+06    9.37e+06
# C45-365     4.124e+06   3.54e-09   1.16e+15      0.000    4.12e+06    4.12e+06
# S46-365     8.272e+06   2.29e-09   3.62e+15      0.000    8.27e+06    8.27e+06
# C46-365     2.001e+06   4.93e-10   4.06e+15      0.000       2e+06       2e+06
# S47-365     5.477e+06   9.67e-10   5.67e+15      0.000    5.48e+06    5.48e+06
# C47-365     -1.43e+07   4.55e-09  -3.14e+15      0.000   -1.43e+07   -1.43e+07
# S48-365     2.417e+07   5.17e-10   4.67e+16      0.000    2.42e+07    2.42e+07
# C48-365     5.839e+06   3.14e-09   1.86e+15      0.000    5.84e+06    5.84e+06
# S49-365     7.166e+06   2.32e-09   3.09e+15      0.000    7.17e+06    7.17e+06
# C49-365    -5.268e+05   3.34e-09  -1.58e+14      0.000   -5.27e+05   -5.27e+05
# S50-365    -4.791e+06   8.52e-09  -5.62e+14      0.000   -4.79e+06   -4.79e+06
# C50-365     1.361e+07   4.38e-09   3.11e+15      0.000    1.36e+07    1.36e+07
# S51-365     2.879e+06   2.42e-09   1.19e+15      0.000    2.88e+06    2.88e+06
# C51-365    -4.702e+05   6.93e-09  -6.78e+13      0.000    -4.7e+05    -4.7e+05
# S52-365    -4.132e+06   1.08e-08  -3.81e+14      0.000   -4.13e+06   -4.13e+06
# C52-365    -1.048e+07   7.12e-09  -1.47e+15      0.000   -1.05e+07   -1.05e+07
# S53-365     6.742e+06    1.3e-09   5.18e+15      0.000    6.74e+06    6.74e+06
# C53-365    -7.865e+06   4.07e-09  -1.93e+15      0.000   -7.87e+06   -7.87e+06
# S54-365     1.461e+07   1.53e-08   9.52e+14      0.000    1.46e+07    1.46e+07
# C54-365    -7.092e+06   1.77e-09     -4e+15      0.000   -7.09e+06   -7.09e+06
# S55-365    -1.573e+06   1.31e-08   -1.2e+14      0.000   -1.57e+06   -1.57e+06
# C55-365     6.588e+06    1.6e-08   4.11e+14      0.000    6.59e+06    6.59e+06
# S56-365      1.31e+07   9.03e-09   1.45e+15      0.000    1.31e+07    1.31e+07
# C56-365    -5.899e+05   7.46e-09  -7.91e+13      0.000    -5.9e+05    -5.9e+05
# S57-365     2.091e+06    9.8e-10   2.13e+15      0.000    2.09e+06    2.09e+06
# C57-365      1.51e+06   6.03e-09    2.5e+14      0.000    1.51e+06    1.51e+06
# S58-365     4.507e+06   1.23e-08   3.67e+14      0.000    4.51e+06    4.51e+06
# C58-365    -6.379e+06   8.29e-10   -7.7e+15      0.000   -6.38e+06   -6.38e+06
# S59-365     9.896e+06   1.31e-08   7.57e+14      0.000     9.9e+06     9.9e+06
# C59-365     9.606e+06   4.06e-09   2.37e+15      0.000    9.61e+06    9.61e+06
# S60-365    -1.631e+07      2e-09  -8.17e+15      0.000   -1.63e+07   -1.63e+07
# C60-365    -1.172e+07   4.99e-09  -2.35e+15      0.000   -1.17e+07   -1.17e+07
# S61-365    -2.086e+06   8.55e-09  -2.44e+14      0.000   -2.09e+06   -2.09e+06
# C61-365     -1.93e+07   5.18e-10  -3.72e+16      0.000   -1.93e+07   -1.93e+07
# S62-365     2.858e+07   1.87e-08   1.53e+15      0.000    2.86e+07    2.86e+07
# C62-365    -1.531e+07   1.24e-09  -1.24e+16      0.000   -1.53e+07   -1.53e+07
# S63-365    -8.404e+06   1.28e-08  -6.58e+14      0.000    -8.4e+06    -8.4e+06
# C63-365    -1.998e+06    5.7e-09  -3.51e+14      0.000      -2e+06      -2e+06
# S64-365     4.964e+06   9.96e-09   4.98e+14      0.000    4.96e+06    4.96e+06
# C64-365    -4.176e+06   4.15e-09  -1.01e+15      0.000   -4.18e+06   -4.18e+06
# S65-365     1.976e+05   2.13e-08   9.28e+12      0.000    1.98e+05    1.98e+05
# C65-365     9.229e+06   7.14e-09   1.29e+15      0.000    9.23e+06    9.23e+06
# S66-365    -1.076e+06   1.18e-08  -9.14e+13      0.000   -1.08e+06   -1.08e+06
# C66-365     1.211e+07   7.76e-09   1.56e+15      0.000    1.21e+07    1.21e+07
# S67-365    -1.153e+07   6.75e-09  -1.71e+15      0.000   -1.15e+07   -1.15e+07
# C67-365     1.421e+07    7.3e-09   1.95e+15      0.000    1.42e+07    1.42e+07
# S68-365     5.299e+06   2.49e-09   2.13e+15      0.000     5.3e+06     5.3e+06
# C68-365    -1.381e+06    7.1e-09  -1.95e+14      0.000   -1.38e+06   -1.38e+06
# S69-365     4.595e+06   1.83e-08   2.51e+14      0.000     4.6e+06     4.6e+06
# C69-365    -3.676e+06   4.12e-09  -8.92e+14      0.000   -3.68e+06   -3.68e+06
# S70-365     1.921e+07   1.36e-08   1.41e+15      0.000    1.92e+07    1.92e+07
# C70-365    -9.686e+06   8.96e-09  -1.08e+15      0.000   -9.69e+06   -9.69e+06
# S71-365     2.264e+05   4.95e-09   4.57e+13      0.000    2.26e+05    2.26e+05
# C71-365     6.251e+06   3.48e-09    1.8e+15      0.000    6.25e+06    6.25e+06
# S72-365    -8.881e+06   2.01e-08  -4.42e+14      0.000   -8.88e+06   -8.88e+06
# C72-365     1.387e+07   6.89e-09   2.01e+15      0.000    1.39e+07    1.39e+07
# S73-365     -1.72e+07   9.25e-10  -1.86e+16      0.000   -1.72e+07   -1.72e+07
# C73-365    -1.539e+05    1.1e-08   -1.4e+13      0.000   -1.54e+05   -1.54e+05
# S74-365     8.906e+06   5.56e-09    1.6e+15      0.000    8.91e+06    8.91e+06
# C74-365     -1.24e+07   6.36e-09  -1.95e+15      0.000   -1.24e+07   -1.24e+07
# S75-365    -9.455e+06   1.12e-09  -8.47e+15      0.000   -9.46e+06   -9.46e+06
# C75-365    -3.356e+05   6.41e-10  -5.24e+14      0.000   -3.36e+05   -3.36e+05
# S76-365     1.022e+07   8.55e-09   1.19e+15      0.000    1.02e+07    1.02e+07
# C76-365    -4.782e+06   5.59e-09  -8.55e+14      0.000   -4.78e+06   -4.78e+06
# S77-365     5.565e+06   2.96e-09   1.88e+15      0.000    5.57e+06    5.57e+06
# C77-365     1.159e+07   1.46e-08   7.93e+14      0.000    1.16e+07    1.16e+07
# S78-365     2.022e+06   7.21e-09   2.81e+14      0.000    2.02e+06    2.02e+06
# C78-365     7.278e+06   5.56e-10   1.31e+16      0.000    7.28e+06    7.28e+06
# S79-365    -8.764e+06   8.82e-09  -9.94e+14      0.000   -8.76e+06   -8.76e+06
# C79-365    -9.837e+05   4.06e-09  -2.42e+14      0.000   -9.84e+05   -9.84e+05
# S80-365     8.469e+06   5.46e-09   1.55e+15      0.000    8.47e+06    8.47e+06
# C80-365     2.055e+05   1.33e-09   1.54e+14      0.000    2.05e+05    2.05e+05
# S81-365     1.313e+07   3.91e-09   3.35e+15      0.000    1.31e+07    1.31e+07
# C81-365    -1.412e+06   1.71e-09  -8.24e+14      0.000   -1.41e+06   -1.41e+06
# S82-365     5.987e+06   2.97e-09   2.02e+15      0.000    5.99e+06    5.99e+06
# C82-365     1.091e+07    3.9e-09   2.79e+15      0.000    1.09e+07    1.09e+07
# S83-365     1.631e+07   7.29e-09   2.24e+15      0.000    1.63e+07    1.63e+07
# C83-365      1.25e+07   8.92e-09    1.4e+15      0.000    1.25e+07    1.25e+07
# S84-365    -8.265e+06   3.09e-09  -2.67e+15      0.000   -8.27e+06   -8.27e+06
# C84-365    -5.318e+06   4.37e-09  -1.22e+15      0.000   -5.32e+06   -5.32e+06
# S85-365     -1.07e+07   1.35e-08  -7.95e+14      0.000   -1.07e+07   -1.07e+07
# C85-365     7.941e+06   2.28e-09   3.49e+15      0.000    7.94e+06    7.94e+06
# S86-365      6.39e+06   4.51e-09   1.42e+15      0.000    6.39e+06    6.39e+06
# C86-365    -5.844e+05   1.01e-08  -5.79e+13      0.000   -5.84e+05   -5.84e+05
# S87-365    -7.363e+06   1.13e-09  -6.49e+15      0.000   -7.36e+06   -7.36e+06
# C87-365     7.245e+06    2.5e-09    2.9e+15      0.000    7.25e+06    7.25e+06
# S88-365     -7.71e+06   6.06e-09  -1.27e+15      0.000   -7.71e+06   -7.71e+06
# C88-365    -5.668e+05   1.52e-09  -3.72e+14      0.000   -5.67e+05   -5.67e+05
# S89-365    -1.327e+07   1.58e-09  -8.37e+15      0.000   -1.33e+07   -1.33e+07
# C89-365     6.198e+06   1.85e-09   3.35e+15      0.000     6.2e+06     6.2e+06
# S90-365     1.219e+07   9.87e-09   1.23e+15      0.000    1.22e+07    1.22e+07
# C90-365     3.016e+06   1.06e-08   2.84e+14      0.000    3.02e+06    3.02e+06
# S91-365    -1.466e+07   1.33e-08   -1.1e+15      0.000   -1.47e+07   -1.47e+07
# C91-365     2.481e+04   9.76e-09   2.54e+12      0.000    2.48e+04    2.48e+04
# S92-365    -1.259e+06   1.59e-09  -7.92e+14      0.000   -1.26e+06   -1.26e+06
# C92-365    -4.401e+06    1.8e-08  -2.44e+14      0.000    -4.4e+06    -4.4e+06
# S93-365    -5.175e+06   7.82e-09  -6.62e+14      0.000   -5.17e+06   -5.17e+06
# C93-365    -5.139e+06   1.48e-08  -3.47e+14      0.000   -5.14e+06   -5.14e+06
# S94-365    -1.364e+07   1.22e-09  -1.12e+16      0.000   -1.36e+07   -1.36e+07
# C94-365    -3.128e+06    7.2e-09  -4.34e+14      0.000   -3.13e+06   -3.13e+06
# S95-365    -5.168e+06   1.06e-08  -4.86e+14      0.000   -5.17e+06   -5.17e+06
# C95-365    -4.909e+06   1.98e-08  -2.48e+14      0.000   -4.91e+06   -4.91e+06
# S96-365     3.008e+06   2.53e-09   1.19e+15      0.000    3.01e+06    3.01e+06
# C96-365     2.365e+06   7.91e-09   2.99e+14      0.000    2.36e+06    2.36e+06
# S97-365     6.677e+06   4.37e-09   1.53e+15      0.000    6.68e+06    6.68e+06
# C97-365    -9.913e+06    5.4e-09  -1.84e+15      0.000   -9.91e+06   -9.91e+06
# S98-365    -2.003e+07    3.9e-09  -5.13e+15      0.000      -2e+07      -2e+07
# C98-365     3.893e+06   1.27e-08   3.06e+14      0.000    3.89e+06    3.89e+06
# S99-365     2.283e+05   1.49e-08   1.53e+13      0.000    2.28e+05    2.28e+05
# C99-365     8.998e+06   2.72e-08    3.3e+14      0.000       9e+06       9e+06
# S100-365    6.766e+06   6.48e-10   1.04e+16      0.000    6.77e+06    6.77e+06
# C100-365    1.154e+07    8.5e-09   1.36e+15      0.000    1.15e+07    1.15e+07
# S101-365    2.234e+06   5.37e-09   4.16e+14      0.000    2.23e+06    2.23e+06
# C101-365   -2.952e+06   6.35e-09  -4.65e+14      0.000   -2.95e+06   -2.95e+06
# S102-365     1.85e+07   7.37e-09   2.51e+15      0.000    1.85e+07    1.85e+07
# C102-365   -4.508e+06   3.99e-09  -1.13e+15      0.000   -4.51e+06   -4.51e+06
# S103-365    7.106e+06   3.73e-09    1.9e+15      0.000    7.11e+06    7.11e+06
# C103-365    9.108e+06   1.27e-08   7.18e+14      0.000    9.11e+06    9.11e+06
# S104-365    1.041e+07   9.59e-09   1.09e+15      0.000    1.04e+07    1.04e+07
# C104-365   -2.862e+06   3.57e-10  -8.02e+15      0.000   -2.86e+06   -2.86e+06
# S105-365   -1.035e+07   3.45e-09     -3e+15      0.000   -1.03e+07   -1.03e+07
# C105-365   -2.246e+06   2.88e-09   -7.8e+14      0.000   -2.25e+06   -2.25e+06
# S106-365   -9.291e+06   5.99e-09  -1.55e+15      0.000   -9.29e+06   -9.29e+06
# C106-365    6.808e+06    1.3e-08   5.23e+14      0.000    6.81e+06    6.81e+06
# S107-365    9.131e+06   4.83e-09   1.89e+15      0.000    9.13e+06    9.13e+06
# C107-365    -8.41e+06   4.58e-09  -1.83e+15      0.000   -8.41e+06   -8.41e+06
# S108-365    8.948e+06   8.49e-09   1.05e+15      0.000    8.95e+06    8.95e+06
# C108-365    1.154e+07   4.08e-09   2.83e+15      0.000    1.15e+07    1.15e+07
# S109-365    7.063e+06   1.51e-08   4.66e+14      0.000    7.06e+06    7.06e+06
# C109-365   -2.966e+06   2.98e-09  -9.95e+14      0.000   -2.97e+06   -2.97e+06
# S110-365    1.551e+07   3.14e-10   4.94e+16      0.000    1.55e+07    1.55e+07
# C110-365   -1.613e+07   1.27e-08  -1.27e+15      0.000   -1.61e+07   -1.61e+07
# S111-365    4.687e+06   4.46e-09   1.05e+15      0.000    4.69e+06    4.69e+06
# C111-365   -5.792e+06   4.64e-09  -1.25e+15      0.000   -5.79e+06   -5.79e+06
# S112-365    3.132e+05   5.44e-09   5.75e+13      0.000    3.13e+05    3.13e+05
# C112-365    -1.91e+06   1.37e-08  -1.39e+14      0.000   -1.91e+06   -1.91e+06
# S113-365    6.023e+06   3.57e-09   1.69e+15      0.000    6.02e+06    6.02e+06
# C113-365   -5.323e+06   2.56e-09  -2.08e+15      0.000   -5.32e+06   -5.32e+06
# S114-365   -6.958e+06   3.59e-09  -1.94e+15      0.000   -6.96e+06   -6.96e+06
# C114-365      1.1e+07   9.28e-09   1.19e+15      0.000     1.1e+07     1.1e+07
# S115-365   -6.035e+05   3.22e-09  -1.87e+14      0.000   -6.04e+05   -6.04e+05
# C115-365   -6.446e+06   1.96e-08  -3.29e+14      0.000   -6.45e+06   -6.45e+06
# S116-365   -4.524e+05   1.97e-08   -2.3e+13      0.000   -4.52e+05   -4.52e+05
# C116-365    8.698e+06   5.49e-09   1.58e+15      0.000     8.7e+06     8.7e+06
# S117-365   -7.632e+06   8.06e-09  -9.47e+14      0.000   -7.63e+06   -7.63e+06
# C117-365    4.192e+06   6.32e-09   6.64e+14      0.000    4.19e+06    4.19e+06
# S118-365   -7.361e+06   3.08e-09  -2.39e+15      0.000   -7.36e+06   -7.36e+06
# C118-365    7.534e+06   8.06e-10   9.34e+15      0.000    7.53e+06    7.53e+06
# S119-365    -7.28e+06      8e-09   -9.1e+14      0.000   -7.28e+06   -7.28e+06
# C119-365   -1.485e+07   1.48e-09  -1.01e+16      0.000   -1.48e+07   -1.48e+07
# S120-365    1.093e+07   3.45e-09   3.17e+15      0.000    1.09e+07    1.09e+07
# C120-365   -8.901e+06   2.12e-09   -4.2e+15      0.000    -8.9e+06    -8.9e+06
# S121-365   -3.488e+06   6.73e-09  -5.18e+14      0.000   -3.49e+06   -3.49e+06
# C121-365    5.394e+05   2.46e-09   2.19e+14      0.000    5.39e+05    5.39e+05
# S122-365    4.302e+05   3.58e-10    1.2e+15      0.000     4.3e+05     4.3e+05
# C122-365    1.492e+06   4.99e-10   2.99e+15      0.000    1.49e+06    1.49e+06
# S123-365   -5.746e+06    1.6e-08  -3.59e+14      0.000   -5.75e+06   -5.75e+06
# C123-365    8.965e+06    5.2e-09   1.73e+15      0.000    8.97e+06    8.97e+06
# S124-365    4.435e+06   1.92e-09   2.31e+15      0.000    4.43e+06    4.43e+06
# C124-365    1.454e+06   1.36e-08   1.07e+14      0.000    1.45e+06    1.45e+06
# S125-365    1.059e+07   4.77e-09   2.22e+15      0.000    1.06e+07    1.06e+07
# C125-365    7.924e+06   2.24e-10   3.53e+16      0.000    7.92e+06    7.92e+06
# S126-365    5.911e+06   2.54e-09   2.33e+15      0.000    5.91e+06    5.91e+06
# C126-365    4.818e+06    2.7e-09   1.79e+15      0.000    4.82e+06    4.82e+06
# S127-365    8.471e+06   1.04e-08   8.18e+14      0.000    8.47e+06    8.47e+06
# C127-365   -6.122e+06   5.02e-09  -1.22e+15      0.000   -6.12e+06   -6.12e+06
# S128-365    2.695e+06   6.14e-09   4.39e+14      0.000     2.7e+06     2.7e+06
# C128-365     6.77e+06   1.09e-09   6.19e+15      0.000    6.77e+06    6.77e+06
# S129-365   -1.041e+07   1.09e-08  -9.57e+14      0.000   -1.04e+07   -1.04e+07
# C129-365   -6.679e+06   1.16e-09  -5.76e+15      0.000   -6.68e+06   -6.68e+06
# S130-365    -1.49e+07   1.59e-08  -9.37e+14      0.000   -1.49e+07   -1.49e+07
# C130-365    4.236e+06   1.06e-08      4e+14      0.000    4.24e+06    4.24e+06
# S131-365   -8.827e+05   4.92e-09  -1.79e+14      0.000   -8.83e+05   -8.83e+05
# C131-365    1.054e+07   8.97e-09   1.17e+15      0.000    1.05e+07    1.05e+07
# S132-365    2.828e+06   8.36e-09   3.38e+14      0.000    2.83e+06    2.83e+06
# C132-365   -4.371e+05    1.6e-09  -2.74e+14      0.000   -4.37e+05   -4.37e+05
# S133-365    1.242e+07   8.89e-09    1.4e+15      0.000    1.24e+07    1.24e+07
# C133-365     1.49e+07   1.27e-08   1.17e+15      0.000    1.49e+07    1.49e+07
# S134-365   -1.174e+06   1.51e-08  -7.76e+13      0.000   -1.17e+06   -1.17e+06
# C134-365   -3.849e+05   5.73e-10  -6.72e+14      0.000   -3.85e+05   -3.85e+05
# S135-365    1.103e+06    6.3e-09   1.75e+14      0.000     1.1e+06     1.1e+06
# C135-365   -2.491e+06   1.84e-08  -1.35e+14      0.000   -2.49e+06   -2.49e+06
# S136-365   -1.702e+07   7.95e-10  -2.14e+16      0.000    -1.7e+07    -1.7e+07
# C136-365   -5.712e+06   1.59e-09  -3.59e+15      0.000   -5.71e+06   -5.71e+06
# S137-365   -1.041e+07   3.75e-09  -2.77e+15      0.000   -1.04e+07   -1.04e+07
# C137-365    1.432e+06   3.12e-09   4.59e+14      0.000    1.43e+06    1.43e+06
# S138-365    7.808e+06   3.13e-09   2.49e+15      0.000    7.81e+06    7.81e+06
# C138-365    8.308e+06   1.72e-09   4.82e+15      0.000    8.31e+06    8.31e+06
# S139-365   -3.054e+06   9.25e-09   -3.3e+14      0.000   -3.05e+06   -3.05e+06
# C139-365   -5.239e+05   1.96e-09  -2.67e+14      0.000   -5.24e+05   -5.24e+05
# S140-365   -4.037e+06   8.25e-09  -4.89e+14      0.000   -4.04e+06   -4.04e+06
# C140-365    3.576e+06   4.26e-09    8.4e+14      0.000    3.58e+06    3.58e+06
# S141-365   -4.613e+06    1.4e-08   -3.3e+14      0.000   -4.61e+06   -4.61e+06
# C141-365   -2.687e+06   6.68e-09  -4.02e+14      0.000   -2.69e+06   -2.69e+06
# S142-365   -1.075e+07    3.8e-09  -2.83e+15      0.000   -1.07e+07   -1.07e+07
# C142-365    1.026e+07   7.13e-09   1.44e+15      0.000    1.03e+07    1.03e+07
# S143-365   -6.248e+06    7.9e-09  -7.91e+14      0.000   -6.25e+06   -6.25e+06
# C143-365   -5.939e+06   5.33e-10  -1.11e+16      0.000   -5.94e+06   -5.94e+06
# S144-365    1.233e+07    3.3e-09   3.74e+15      0.000    1.23e+07    1.23e+07
# C144-365   -1.482e+07   1.14e-08   -1.3e+15      0.000   -1.48e+07   -1.48e+07
# S145-365    5.896e+06   2.87e-09   2.05e+15      0.000     5.9e+06     5.9e+06
# C145-365     6.07e+06   1.38e-09   4.41e+15      0.000    6.07e+06    6.07e+06
# S146-365   -1.068e+07    1.2e-08   -8.9e+14      0.000   -1.07e+07   -1.07e+07
# C146-365    1.166e+06   8.11e-09   1.44e+14      0.000    1.17e+06    1.17e+06
# S147-365   -1.007e+07   5.43e-09  -1.85e+15      0.000   -1.01e+07   -1.01e+07
# C147-365    1.702e+05   1.93e-08    8.8e+12      0.000     1.7e+05     1.7e+05
# S148-365   -3.881e+06   2.93e-09  -1.33e+15      0.000   -3.88e+06   -3.88e+06
# C148-365   -4.694e+06    6.7e-09     -7e+14      0.000   -4.69e+06   -4.69e+06
# S149-365    7.134e+06   1.41e-08   5.07e+14      0.000    7.13e+06    7.13e+06
# C149-365     8.29e+06   2.27e-08   3.65e+14      0.000    8.29e+06    8.29e+06
# S150-365    1.717e+07   1.46e-08   1.17e+15      0.000    1.72e+07    1.72e+07
# C150-365   -3.041e+06   6.81e-09  -4.47e+14      0.000   -3.04e+06   -3.04e+06
# S151-365   -6.703e+06   3.73e-09   -1.8e+15      0.000    -6.7e+06    -6.7e+06
# C151-365    6.294e+06   5.55e-09   1.13e+15      0.000    6.29e+06    6.29e+06
# S152-365    4.313e+06    1.2e-09    3.6e+15      0.000    4.31e+06    4.31e+06
# C152-365    1.516e+07   1.42e-08   1.07e+15      0.000    1.52e+07    1.52e+07
# S153-365    -1.17e+07   4.21e-09  -2.78e+15      0.000   -1.17e+07   -1.17e+07
# C153-365   -3.752e+06   1.41e-08  -2.67e+14      0.000   -3.75e+06   -3.75e+06
# S154-365   -9.088e+06   7.44e-09  -1.22e+15      0.000   -9.09e+06   -9.09e+06
# C154-365   -5.814e+06   6.52e-10  -8.92e+15      0.000   -5.81e+06   -5.81e+06
# S155-365    5.604e+06   9.32e-09   6.01e+14      0.000     5.6e+06     5.6e+06
# C155-365     1.34e+06   2.78e-09   4.81e+14      0.000    1.34e+06    1.34e+06
# S156-365   -1.703e+06   1.08e-09  -1.58e+15      0.000    -1.7e+06    -1.7e+06
# C156-365   -8.351e+06   2.29e-08  -3.64e+14      0.000   -8.35e+06   -8.35e+06
# S157-365   -1.145e+07   8.32e-10  -1.38e+16      0.000   -1.15e+07   -1.15e+07
# C157-365    3.857e+06   3.22e-09    1.2e+15      0.000    3.86e+06    3.86e+06
# S158-365   -5.734e+06    1.9e-09  -3.03e+15      0.000   -5.73e+06   -5.73e+06
# C158-365   -5.916e+06   7.77e-09  -7.61e+14      0.000   -5.92e+06   -5.92e+06
# S159-365     4.09e+06   5.92e-09    6.9e+14      0.000    4.09e+06    4.09e+06
# C159-365    4.034e+06   1.68e-08   2.41e+14      0.000    4.03e+06    4.03e+06
# S160-365   -8.242e+06   3.35e-09  -2.46e+15      0.000   -8.24e+06   -8.24e+06
# C160-365   -6.671e+06   9.64e-09  -6.92e+14      0.000   -6.67e+06   -6.67e+06
# S161-365   -4.634e+06   4.94e-09  -9.38e+14      0.000   -4.63e+06   -4.63e+06
# C161-365    4.039e+06   6.04e-09   6.69e+14      0.000    4.04e+06    4.04e+06
# S162-365    6.892e+06   2.33e-08   2.95e+14      0.000    6.89e+06    6.89e+06
# C162-365   -2.425e+06   9.57e-09  -2.53e+14      0.000   -2.43e+06   -2.43e+06
# S163-365    8.818e+06   5.58e-09   1.58e+15      0.000    8.82e+06    8.82e+06
# C163-365   -1.006e+07   6.67e-09  -1.51e+15      0.000   -1.01e+07   -1.01e+07
# S164-365   -1.276e+06   6.75e-10  -1.89e+15      0.000   -1.28e+06   -1.28e+06
# C164-365   -1.104e+07   8.18e-09  -1.35e+15      0.000    -1.1e+07    -1.1e+07
# S165-365    2.028e+06   1.23e-08   1.65e+14      0.000    2.03e+06    2.03e+06
# C165-365   -5.067e+06   1.36e-09  -3.74e+15      0.000   -5.07e+06   -5.07e+06
# S166-365   -6.268e+06    8.1e-09  -7.74e+14      0.000   -6.27e+06   -6.27e+06
# C166-365   -5.207e+06   1.73e-10     -3e+16      0.000   -5.21e+06   -5.21e+06
# S167-365   -3.231e+06   2.77e-09  -1.17e+15      0.000   -3.23e+06   -3.23e+06
# C167-365    1.409e+06   6.05e-09   2.33e+14      0.000    1.41e+06    1.41e+06
# S168-365     1.14e+06   1.91e-09   5.96e+14      0.000    1.14e+06    1.14e+06
# C168-365   -6.696e+06   1.14e-09  -5.88e+15      0.000    -6.7e+06    -6.7e+06
# S169-365    -3.27e+06   9.82e-10  -3.33e+15      0.000   -3.27e+06   -3.27e+06
# C169-365    5.705e+06   4.05e-09   1.41e+15      0.000     5.7e+06     5.7e+06
# S170-365    7.048e+06    6.1e-09   1.16e+15      0.000    7.05e+06    7.05e+06
# C170-365    6.373e+06   2.35e-09   2.71e+15      0.000    6.37e+06    6.37e+06
# S171-365    -4.24e+06   1.11e-08  -3.84e+14      0.000   -4.24e+06   -4.24e+06
# C171-365   -1.952e+06   7.62e-10  -2.56e+15      0.000   -1.95e+06   -1.95e+06
# S172-365    7.189e+06   2.15e-09   3.34e+15      0.000    7.19e+06    7.19e+06
# C172-365    1.708e+06   2.91e-09   5.88e+14      0.000    1.71e+06    1.71e+06
# S173-365    6.838e+05   1.18e-08   5.79e+13      0.000    6.84e+05    6.84e+05
# C173-365    1.927e+05   5.01e-09   3.85e+13      0.000    1.93e+05    1.93e+05
# S174-365   -5.556e+06   1.85e-08  -3.01e+14      0.000   -5.56e+06   -5.56e+06
# C174-365   -9.956e+06   3.36e-09  -2.96e+15      0.000   -9.96e+06   -9.96e+06
# S175-365   -1.212e+07    6.6e-09  -1.83e+15      0.000   -1.21e+07   -1.21e+07
# C175-365    -2.43e+06   1.18e-09  -2.06e+15      0.000   -2.43e+06   -2.43e+06
# S176-365    1.387e+06   5.49e-09   2.53e+14      0.000    1.39e+06    1.39e+06
# C176-365   -7.924e+06   4.74e-09  -1.67e+15      0.000   -7.92e+06   -7.92e+06
# S177-365   -1.546e+06   1.78e-08  -8.67e+13      0.000   -1.55e+06   -1.55e+06
# C177-365    3.619e+05   1.15e-08   3.16e+13      0.000    3.62e+05    3.62e+05
# S178-365   -2.149e+06   1.84e-09  -1.17e+15      0.000   -2.15e+06   -2.15e+06
# C178-365    2.985e+06   1.52e-09   1.97e+15      0.000    2.99e+06    2.99e+06
# S179-365   -5.765e+06   3.12e-10  -1.85e+16      0.000   -5.76e+06   -5.76e+06
# C179-365    4.483e+06   3.19e-09   1.41e+15      0.000    4.48e+06    4.48e+06
# S180-365    7.412e+06   2.64e-10   2.81e+16      0.000    7.41e+06    7.41e+06
# C180-365    7.141e+06   1.36e-09   5.25e+15      0.000    7.14e+06    7.14e+06
# S181-365    6.472e+06   5.07e-09   1.28e+15      0.000    6.47e+06    6.47e+06
# C181-365   -7.037e+06   1.03e-09   -6.8e+15      0.000   -7.04e+06   -7.04e+06
# S182-365    4.184e+05   9.35e-09   4.48e+13      0.000    4.18e+05    4.18e+05
# C182-365    2.023e+07   1.25e-08   1.62e+15      0.000    2.02e+07    2.02e+07
# ar.L1         -0.1614      0.564     -0.286      0.775      -1.267       0.944
# ar.L2         -0.0363      0.457     -0.079      0.937      -0.931       0.859
# ar.L3          0.3194      0.381      0.837      0.402      -0.428       1.067
# ar.L4          0.6840      0.480      1.425      0.154      -0.257       1.625
# ma.L1          0.5486      0.563      0.975      0.329      -0.554       1.651
# ma.L2          0.3838      0.265      1.447      0.148      -0.136       0.904
# ma.L3         -0.0825      0.350     -0.236      0.814      -0.769       0.603
# ma.L4         -0.6368      0.376     -1.694      0.090      -1.374       0.100
# ma.L5         -0.2015      0.097     -2.087      0.037      -0.391      -0.012
# ma.L6         -0.0766      0.065     -1.183      0.237      -0.204       0.050
# sigma2      4.672e+16   6.62e-18   7.06e+33      0.000    4.67e+16    4.67e+16
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 4.74
# Prob(Q):                              0.97   Prob(JB):                         0.09
# Heteroskedasticity (H):               1.11   Skew:                             0.12
# Prob(H) (two-sided):                  0.26   Kurtosis:                         3.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.51e+48. Standard errors may be unstable.
# """

# %%
model.plot_diagnostics(figsize=(15,8));

# %%
def execute_forecast(pred, df_actual):
    results = pd.DataFrame(data={'date': df_actual.index, 'Predictions': pred, 'Actuals': df_actual[ATTR_NOW].values})
    results.set_index('date', inplace=True)
    
    plt.figure(figsize=(18,8))
    plt.title(f'Peramalan {ATTR_NAME} ARIMA')
    plt.plot(results.Predictions, 'b', label='Predictions')
    plt.plot(results.Actuals, 'r--', label='Actuals')
    plt.legend()
    plt.show
    
    MAE = mean_absolute_error(results.Actuals, results.Predictions)
    RMSE = sqrt(mean_squared_error(results.Actuals, results.Predictions))
    print(f'Mean Absolute Error is\t\t: {MAE}')
    print(f'Root Mean Squared Error is\t: {RMSE}')
    
    return results, MAE, RMSE

# %%
predictions = model.predict(n_periods = len(dtest), exogenous=test_exg)

# %%
predictions_inv = inv_boxcox(predictions, trans_lambdas)

# %%
results, __, __ = execute_forecast(predictions_inv, dtest)

# %% [markdown]
# # Period Forecasting

# %%
def period_forecast(model_loc, period, data, exog):
    with open(model_loc, 'rb') as pkl:
        model = pickle.load(pkl) 
    predictions = []
    prog_count = 0
    for index in np.arange(0, len(data), period):
        if index+period > len(data) - 1:
            period = int(len(data) - index)
        print(f'Forecasting {period}-step from index {index}')
        results = model.predict(n_periods=period, exogenous=exog.iloc[index:index+period])
        for result in results:
            prog_count += 1
            predictions.append(result)
            print(f"result: {result}\t\tprocess: {prog_count}/{len(data)}")
        print('Updating the model...')
        model.update(data.iloc[index:index+period], exogenous=exog.iloc[index:index+period])
            
    return np.array(predictions)

# %%
test_trans = boxcox(dtest[ATTR_NOW], lmbda=trans_lambdas)
df_dtest_trans = dtest.copy()
df_dtest_trans[ATTR_NOW] = test_trans

# %% [markdown]
# ### Forecast scenario 1 : 1 time step

# %%
# %%time
sc1_forecast = period_forecast(model_loc, 1, df_dtest_trans, test_exg)

# %%
sc1_forecast_inv = inv_boxcox(sc1_forecast, trans_lambdas)

# %%
sc1_forecast_df, __, __ = execute_forecast(sc1_forecast_inv, dtest)

# %% [markdown]
# ### Forecast scenario 2 : 3 time step

# %%
# %%time
sc2_forecast = period_forecast(model_loc, 3, df_dtest_trans, test_exg)

# %%
sc2_forecast_inv = inv_boxcox(sc2_forecast, trans_lambdas)

# %%
sc2_forecast_df, __, __ = execute_forecast(sc2_forecast_inv, dtest)

# %% [markdown]
# ### Forecast scenario 3 : 7 time step

# %%
# %%time
sc3_forecast = period_forecast(model_loc, 7, df_dtest_trans, test_exg)

# %%
sc3_forecast_inv = inv_boxcox(sc3_forecast, trans_lambdas)

# %%
sc3_forecast_df, __, __ = execute_forecast(sc3_forecast_inv, dtest)

# %% [markdown]
# # Collecting All Predictions Scenario Result

# %%
def plot_forecasts_result(res_df):
    title = 'Peramalan ' + ATTR_NAME + ' ARIMA'
    
    plt.figure(figsize=(18,8))
    plt.title(title)
    plt.plot(res_df['scn-1'], 'r-', label='1-step forecast')
    plt.plot(res_df['scn-2'], 'b-', label='3-step forecast')
    plt.plot(res_df['scn-3'], 'g-', label='7-step forecast')
    plt.plot(res_df['Actuals'], color='black', linestyle=':' , label='Actuals')
    plt.legend()

# %%
def col_forcasts_err(res_df):
    for col in [x for x in range(len(forecasts_result.columns)-1)]:
        col_name = res_df.columns[col]
        MAE = mean_absolute_error(res_df['Actuals'], res_df[col_name])
        RMSE = sqrt(mean_squared_error(res_df['Actuals'], res_df[col_name]))
        print('Error for ', col_name)
        print(f'Mean Absolute Error is\t\t: {MAE}')
        print(f'Root Mean Squared Error is\t: {RMSE}')
        print()

# %%
sc1_df_cp = sc1_forecast_df.copy()
sc1_df_cp.columns = ['scn-1', 'Actuals']

sc2_df_cp = sc2_forecast_df.copy()
sc2_df_cp.columns = ['scn-2', 'Actuals']

sc3_df_cp = sc3_forecast_df.copy()
sc3_df_cp.columns = ['scn-3', 'Actuals']

# %%
forecasts_result = pd.concat([sc1_df_cp[[sc1_df_cp.columns[0]]],
                              sc2_df_cp[[sc2_df_cp.columns[0]]],
                              sc3_df_cp[[sc3_df_cp.columns[0]]],
                              sc1_df_cp[[sc3_df_cp.columns[1]]]
                             ],
                               axis='columns')

# %%
plot_forecasts_result(forecasts_result)

# %%
col_forcasts_err(forecasts_result)

# %% [markdown]
# ## Saving forecasts result

# %%
forecasts_result.to_csv('ARIMA_results/'+ATTR_NOW+'.csv')
