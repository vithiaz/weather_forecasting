# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('min_temp_up.csv')
df.date = pd.to_datetime(df.date, format='%Y-%m-%d')
df.set_index('date', inplace=True)
df.head()
# Out:
#             Predictions  Actuals
# date
# 2021-08-15    19.270438     19.3
# 2021-08-16    19.492574     20.8
# 2021-08-17    20.221296     19.0
# 2021-08-18    19.156913     19.4
# 2021-08-19    19.111725     18.9

# %%
plt.plot(df)
