# %%
ATTR_NOW = 'min_temp'

# %%
attr_dict = {
    'min_temp': ('mnt', 'minimum temperature'),
    'max_temp': ('mxt', 'maksimum temperature'),
    'avg_temp': ('avgt', 'average temperature'),
    'avg_humidity': ('hum', 'humidity'),
    'sunshine': ('sun', 'sunshine'),
    'rainfall': ('rain', 'rainfall'),
}

ATTR_CODE = attr_dict[ATTR_NOW][0]
ATTR_NAME = attr_dict[ATTR_NOW][1]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.tsa.stattools as sts
import statsmodels.graphics.tsaplots as sgt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose

from pmdarima.arima import auto_arima, ndiffs, nsdiffs

from sklearn.metrics import mean_absolute_error, mean_squared_error
from math import sqrt

import scipy.stats as stats
from scipy.stats import boxcox
from scipy.special import inv_boxcox
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../attributes_dataset/min_temp.csv')
df.date = pd.to_datetime(df.date, format='%Y-%m-%d')
df.set_index('date', inplace=True)
df.head()
# Out:
#             min_temp
# date
# 2016-01-01      19.0
# 2016-01-02      20.0
# 2016-01-03      21.0
# 2016-01-04      20.0
# 2016-01-05      18.0

# %% [markdown]
# # Splitting Data

# %%
train_ratio = int(len(df) * 0.9)

# %%
dtrain = df.iloc[:train_ratio]
dtest = df.iloc[train_ratio:]

# %%
print(dtrain.shape)
print(dtest.shape)
# Out:
# (2053, 1)
# (229, 1)

# %% [markdown]
# # Visualisasi ACF dan PACF

# %%
lags = 40
fig, ax = plt.subplots(1,2,figsize=(11,3), ylim=(-0.75, 0.75))
plt.suptitle(ATTR_NAME, fontsize=14)
sgt.plot_acf(dtrain, lags=lags, zero=False, ax=ax[0])
sgt.plot_pacf(dtrain, lags=lags, zero=False, ax=ax[1])
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.plot(dtrain)

# %%
dtrain.head(5)
# Out:
#             min_temp
# date
# 2016-01-01      19.0
# 2016-01-02      20.0
# 2016-01-03      21.0
# 2016-01-04      20.0
# 2016-01-05      18.0

# %% [markdown]
# # Stasionary Test (dickey fuller)

# %%
adf = sts.adfuller(dtrain)
print(f'ADF p values\t\t: {adf[1]}')
print(f'ADF statistic values\t: {adf[0]}')
print(f'ADF critical values\t: {adf[4]}')
# Out:
# ADF p values		: 4.304152175816683e-13
# ADF statistic values	: -8.289328267341482
# ADF critical values	: {'1%': -3.433558007578753, '5%': -2.862957140659075, '10%': -2.5675244224821823}

# %%
d_value = ndiffs(dtrain, test='kpss')
d_value
# Out:
# 1

# %%
# p-value < 0.05 tidak stasioner
sts.kpss(dtrain, regression='ct')
# Out:
# (0.22401146525031096,
#  0.01,
#  26,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
plt.figure(figsize=(18,8))
plt.plot(dtrain.loc['2016-01-01':'2017-01-01'])

# %% [markdown]
# # Levene Test

# %%
len_dtrain = len(dtrain)

# %% [raw]
# levgrp_1 = dtrain.min_temp.iloc[int(0.2*len_dtrain):int(0.6*len_dtrain)].values
# levgrp_2 = dtrain.min_temp.iloc[:int(0.4*len_dtrain)].values
# levgrp_3 = dtrain.min_temp.iloc[int(0.5*len_dtrain):].values
# levgrp_4 = dtrain.min_temp.iloc[int(0.2*len_dtrain):].values

# %%
len_dtrain = len(dtrain)
levgrp_1 = dtrain.min_temp.iloc[int(0.2*len_dtrain):int(0.6*len_dtrain)]
levgrp_2 = dtrain.min_temp.iloc[:int(0.4*len_dtrain)]
levgrp_3 = dtrain.min_temp.iloc[int(0.8*len_dtrain):]
levgrp_4 = dtrain.min_temp.iloc[int(0.2*len_dtrain):int(0.9*len_dtrain)]

# %%
#levene p-value > 0.05 == varian stasioner
levene_val = stats.levene(levgrp_1, levgrp_2, levgrp_3, levgrp_4, center='mean')

print(levene_val)
if levene_val[1] > 0.05:
    print('Varian Stasioner')
else:
    print('Varian Tidak Stasioner')
# Out:
# LeveneResult(statistic=5.655536307236176, pvalue=0.0007312938643619805)
# Varian Tidak Stasioner

# %% [markdown]
# ### Need Box-Cox Tranformation

# %%
trans = boxcox(dtrain.min_temp)
dtrain_trans = trans[0]
trans_lambdas = trans[1]

# %%
df_dtrain_trans = dtrain.copy()
df_dtrain_trans[ATTR_NOW] = dtrain_trans

# %% [markdown]
# # Auto Arima Model

# %%
train_exg = pd.read_csv('../R_resource/min_temp_train_exog182.csv')
train_exg = train_exg.drop(columns='Unnamed: 0')

# %%
test_exg = pd.read_csv('../R_resource/min_temp_test_exog182.csv')
test_exg = test_exg.drop(columns='Unnamed: 0')

# %% [raw]
# %%time
# model = auto_arima(df_dtrain_trans, exogenous=train_exg, trace=True, stepwise=True,
#                        max_p=7, max_q=7, d=1)

# %% [markdown]
# # Saving Model

# %%
model_loc = f'ARIMA_models/{ATTR_NOW}.pkl'

# %% [raw]
# ## saving model
#
# with open(model_loc, 'wb') as pkl:
#     pickle.dump(model, pkl)

# %%
## open the model

with open(model_loc, 'rb') as pkl:
    model = pickle.load(pkl)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2053
# Model:               SARIMAX(1, 1, 3)   Log Likelihood              -22006.308
# Date:                Mon, 08 Aug 2022   AIC                          44750.617
# Time:                        07:14:29   BIC                          46826.821
# Sample:                             0   HQIC                         45511.966
#                                - 2053
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# S1-365      2870.2591   1638.654      1.752      0.080    -341.443    6081.961
# C1-365      -613.0395   1668.706     -0.367      0.713   -3883.643    2657.564
# S2-365       143.8258   1234.026      0.117      0.907   -2274.821    2562.473
# C2-365      4342.2096   1210.738      3.586      0.000    1969.207    6715.212
# S3-365      -255.2131   1097.373     -0.233      0.816   -2406.024    1895.598
# C3-365      1562.7690   1103.453      1.416      0.157    -599.959    3725.497
# S4-365      -283.9234   1049.729     -0.270      0.787   -2341.355    1773.508
# C4-365      -208.4433   1037.229     -0.201      0.841   -2241.376    1824.489
# S5-365     -1443.4982    951.296     -1.517      0.129   -3308.004     421.008
# C5-365      2349.1501   1054.666      2.227      0.026     282.043    4416.257
# S6-365      -624.5293   1030.533     -0.606      0.544   -2644.338    1395.279
# C6-365      -646.9808    929.057     -0.696      0.486   -2467.899    1173.937
# S7-365     -1199.3427    907.765     -1.321      0.186   -2978.529     579.843
# C7-365       496.6166    984.227      0.505      0.614   -1432.433    2425.666
# S8-365      -172.7948    981.142     -0.176      0.860   -2095.799    1750.209
# C8-365       -12.1944    858.477     -0.014      0.989   -1694.778    1670.389
# S9-365       738.7720    847.945      0.871      0.384    -923.170    2400.714
# S169-365     404.9473    332.030      1.220      0.223    -245.820    1055.715
# C169-365     424.8589    361.906      1.174      0.240    -284.463    1134.181
# S170-365    -154.3461    358.616     -0.430      0.667    -857.220     548.527
# C170-365      25.4184    334.272      0.076      0.939    -629.742     680.579
# S171-365    -261.8154    353.084     -0.742      0.458    -953.847     430.217
# C171-365     330.2163    341.133      0.968      0.333    -338.391     998.824
# S172-365    -437.3295    349.476     -1.251      0.211   -1122.290     247.631
# C172-365    -268.3965    344.297     -0.780      0.436    -943.207     406.414
# S173-365     279.5215    349.719      0.799      0.424    -405.914     964.957
# C173-365      83.6131    341.837      0.245      0.807    -586.375     753.601
# S174-365    -164.7728    330.117     -0.499      0.618    -811.790     482.244
# C174-365      -7.0602    360.954     -0.020      0.984    -714.516     700.396
# S175-365    -236.4324    354.289     -0.667      0.505    -930.826     457.961
# C175-365     126.5491    332.834      0.380      0.704    -525.793     778.891
# S176-365       0.0465    332.467      0.000      1.000    -651.576     651.669
# C176-365    -119.3026    356.561     -0.335      0.738    -818.149     579.544
# S177-365     144.0768    352.159      0.409      0.682    -546.141     834.295
# C177-365     -84.8424    336.372     -0.252      0.801    -744.120     574.436
# S178-365     186.0245    327.343      0.568      0.570    -455.556     827.605
# C178-365      94.5317    361.391      0.262      0.794    -613.782     802.845
# S179-365     350.4445    360.572      0.972      0.331    -356.265    1057.154
# C179-365    -234.4886    329.032     -0.713      0.476    -879.379     410.402
# S180-365     434.4731    330.974      1.313      0.189    -214.225    1083.171
# C180-365     133.2556    354.464      0.376      0.707    -561.482     827.993
# S181-365     192.3116    346.728      0.555      0.579    -487.263     871.887
# C181-365     -51.8976    342.310     -0.152      0.879    -722.813     619.017
# S182-365    -985.5006    334.888     -2.943      0.003   -1641.869    -329.132
# C182-365    -577.3617    353.492     -1.633      0.102   -1270.193     115.470
# ar.L1          0.8133      0.068     12.008      0.000       0.681       0.946
# ma.L1         -1.4268      0.074    -19.191      0.000      -1.572      -1.281
# ma.L2          0.2906      0.055      5.240      0.000       0.182       0.399
# ma.L3          0.1449      0.040      3.578      0.000       0.066       0.224
# sigma2      1.265e+08        nan        nan        nan         nan         nan
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                23.80
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.90   Skew:                             0.25
# Prob(H) (two-sided):                  0.16   Kurtosis:                         3.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.44e+21. Standard errors may be unstable.
# """

# %%
model.plot_diagnostics(figsize=(15,8));

# %%
def execute_forecast(pred, df_actual):
    results = pd.DataFrame(data={'date': df_actual.index, 'Predictions': pred, 'Actuals': df_actual[ATTR_NOW].values})
    results.set_index('date', inplace=True)
    
    plt.figure(figsize=(18,8))
    plt.title(f'Peramalan {ATTR_NAME} ARIMA')
    plt.plot(results.Predictions, 'b', label='Predictions')
    plt.plot(results.Actuals, 'r--', label='Actuals')
    plt.legend()
    plt.show
    
    MAE = mean_absolute_error(results.Actuals, results.Predictions)
    RMSE = sqrt(mean_squared_error(results.Actuals, results.Predictions))
    print(f'Mean Absolute Error is\t\t: {MAE}')
    print(f'Root Mean Squared Error is\t: {RMSE}')
    
    return results, MAE, RMSE

# %%
predictions = model.predict(n_periods = len(dtest), exogenous=test_exg)

# %%
predictions_inv = inv_boxcox(predictions, trans_lambdas)

# %%
results, __, __ = execute_forecast(predictions_inv, dtest)
# Out:
# Mean Absolute Error is		: 0.9399694462967946
# Root Mean Squared Error is	: 1.1396192398815048

# %% [markdown]
# # Period Forecasting

# %%
def period_forecast(model_loc, period, data, exog):
    with open(model_loc, 'rb') as pkl:
        model = pickle.load(pkl) 
    predictions = []
    prog_count = 0
    for index in np.arange(0, len(data), period):
        if index+period > len(data) - 1:
            period = int(len(data) - index)
        print(f'Forecasting {period}-step from index {index}')
        results = model.predict(n_periods=period, exogenous=exog.iloc[index:index+period])
        for result in results:
            prog_count += 1
            predictions.append(result)
            print(f"result: {result}\t\tprocess: {prog_count}/{len(data)}")
        print('Updating the model...')
        model.update(data.iloc[index:index+period], exogenous=exog.iloc[index:index+period])
            
    return np.array(predictions)

# %%
test_trans = boxcox(dtest[ATTR_NOW], lmbda=trans_lambdas)
df_dtest_trans = dtest.copy()
df_dtest_trans[ATTR_NOW] = test_trans

# %% [markdown]
# ### Forecast scenario 1 : 1 time step

# %%
# %%time
sc1_forecast = period_forecast(model_loc, 1, df_dtest_trans, test_exg)
# Out:
# Forecasting 1-step from index 0
# result: 53447.56411600338		process: 1/229
# Updating the model...
# Forecasting 1-step from index 1
# result: 56058.67329485748		process: 2/229
# Updating the model...
# Forecasting 1-step from index 2
# result: 65309.727519614455		process: 3/229
# Updating the model...
# Forecasting 1-step from index 3
# result: 52149.36421346914		process: 4/229
# Updating the model...
# Forecasting 1-step from index 4
# result: 51639.34569915846		process: 5/229
# Updating the model...
# Forecasting 1-step from index 5
# result: 66285.07083497931		process: 6/229
# Updating the model...
# Forecasting 1-step from index 6
# result: 58385.673003595155		process: 7/229
# Updating the model...
# Forecasting 1-step from index 7
# result: 55208.38696049813		process: 8/229
# Updating the model...
# Forecasting 1-step from index 8
# result: 51382.93652909937		process: 9/229
# Updating the model...
# Forecasting 1-step from index 9
# result: 47814.96213358214		process: 10/229
# Updating the model...
# Forecasting 1-step from index 10
# result: 48526.39102715787		process: 11/229
# Updating the model...
# Forecasting 1-step from index 11
# result: 67299.12892712303		process: 12/229
# Updating the model...
# Forecasting 1-step from index 12
# result: 56962.68305485608		process: 13/229
# Updating the model...
# Forecasting 1-step from index 13
# result: 49543.64164036162		process: 14/229
# Updating the model...
# Forecasting 1-step from index 14
# result: 56528.222142467836		process: 15/229
# Updating the model...
# Forecasting 1-step from index 15
# result: 65742.79772556652		process: 16/229
# Updating the model...
# Forecasting 1-step from index 16
# result: 61268.16080671015		process: 17/229
# Updating the model...
# Forecasting 1-step from index 17
# result: 64511.27609264607		process: 18/229
# Updating the model...
# Forecasting 1-step from index 18
# result: 36434.05415379036		process: 19/229
# Updating the model...
# Forecasting 1-step from index 19
# result: 56906.84372724744		process: 20/229
# Updating the model...
# Forecasting 1-step from index 20
# result: 44300.75452989565		process: 21/229
# Updating the model...
# Forecasting 1-step from index 21
# result: 54200.789199116916		process: 22/229
# Updating the model...
# Forecasting 1-step from index 22
# result: 57337.83918748978		process: 23/229
# Updating the model...
# Forecasting 1-step from index 23
# result: 63152.7940069485		process: 24/229
# Updating the model...
# Forecasting 1-step from index 24
# result: 64466.43566736646		process: 25/229
# Updating the model...
# Forecasting 1-step from index 25
# result: 63241.42979926406		process: 26/229
# Updating the model...
# Forecasting 1-step from index 26
# result: 61142.28836277174		process: 27/229
# Updating the model...
# Forecasting 1-step from index 27
# result: 67585.3700801745		process: 28/229
# Updating the model...
# Forecasting 1-step from index 28
# result: 68997.45947054862		process: 29/229
# Updating the model...
# Forecasting 1-step from index 29
# result: 69006.81052382744		process: 30/229
# Updating the model...
# Forecasting 1-step from index 30
# result: 63498.67854374981		process: 31/229
# Updating the model...
# Forecasting 1-step from index 31
# result: 61218.67074867633		process: 32/229
# Updating the model...
# Forecasting 1-step from index 32
# result: 52231.20154761899		process: 33/229
# Updating the model...
# Forecasting 1-step from index 33
# result: 74425.93260785643		process: 34/229
# Updating the model...
# Forecasting 1-step from index 34
# result: 62847.584572495114		process: 35/229
# Updating the model...
# Forecasting 1-step from index 35
# result: 57270.0811976543		process: 36/229
# Updating the model...
# Forecasting 1-step from index 36
# result: 56795.69053763179		process: 37/229
# Updating the model...
# Forecasting 1-step from index 37
# result: 66272.16563871628		process: 38/229
# Updating the model...
# Forecasting 1-step from index 38
# result: 61374.432988944754		process: 39/229
# Updating the model...
# Forecasting 1-step from index 39
# result: 67044.05456489406		process: 40/229
# Updating the model...
# Forecasting 1-step from index 40
# result: 61988.179112195954		process: 41/229
# Updating the model...
# Forecasting 1-step from index 41
# result: 53951.28814681194		process: 42/229
# Updating the model...
# Forecasting 1-step from index 42
# result: 51205.79792689427		process: 43/229
# Updating the model...
# Forecasting 1-step from index 43
# result: 75542.85111274564		process: 44/229
# Updating the model...
# Forecasting 1-step from index 44
# result: 69791.62530983354		process: 45/229
# Updating the model...
# Forecasting 1-step from index 45
# result: 55480.12902094181		process: 46/229
# Updating the model...
# Forecasting 1-step from index 46
# result: 58958.30559295861		process: 47/229
# Updating the model...
# Forecasting 1-step from index 47
# result: 67390.90178953455		process: 48/229
# Updating the model...
# Forecasting 1-step from index 48
# result: 57101.33924666287		process: 49/229
# Updating the model...
# Forecasting 1-step from index 49
# result: 70406.18012964497		process: 50/229
# Updating the model...
# Forecasting 1-step from index 50
# result: 60839.01919439956		process: 51/229
# Updating the model...
# Forecasting 1-step from index 51
# result: 66412.56769820864		process: 52/229
# Updating the model...
# Forecasting 1-step from index 52
# result: 58563.39579859911		process: 53/229
# Updating the model...
# Forecasting 1-step from index 53
# result: 59284.70849862851		process: 54/229
# Updating the model...
# Forecasting 1-step from index 54
# result: 51288.82349256937		process: 55/229
# Updating the model...
# Forecasting 1-step from index 55
# result: 50952.52631974903		process: 56/229
# Updating the model...
# Forecasting 1-step from index 56
# result: 68199.2443631497		process: 57/229
# Updating the model...
# Forecasting 1-step from index 57
# result: 55838.01046858185		process: 58/229
# Updating the model...
# Forecasting 1-step from index 58
# result: 57882.743579780516		process: 59/229
# Updating the model...
# Forecasting 1-step from index 59
# result: 73086.16122208405		process: 60/229
# Updating the model...
# Forecasting 1-step from index 60
# result: 64093.874135357415		process: 61/229
# Updating the model...
# Forecasting 1-step from index 61
# result: 64076.124947346856		process: 62/229
# Updating the model...
# Forecasting 1-step from index 62
# result: 50269.3626892235		process: 63/229
# Updating the model...
# Forecasting 1-step from index 63
# result: 56964.66950501727		process: 64/229
# Updating the model...
# Forecasting 1-step from index 64
# result: 54222.081126139565		process: 65/229
# Updating the model...
# Forecasting 1-step from index 65
# result: 65861.0455892919		process: 66/229
# Updating the model...
# Forecasting 1-step from index 66
# result: 61245.77564697375		process: 67/229
# Updating the model...
# Forecasting 1-step from index 67
# result: 61855.368920921064		process: 68/229
# Updating the model...
# Forecasting 1-step from index 68
# result: 38592.537518124016		process: 69/229
# Updating the model...
# Forecasting 1-step from index 69
# result: 54742.929699366185		process: 70/229
# Updating the model...
# Forecasting 1-step from index 70
# result: 58606.474212410554		process: 71/229
# Updating the model...
# Forecasting 1-step from index 71
# result: 66784.61681298132		process: 72/229
# Updating the model...
# Forecasting 1-step from index 72
# result: 49778.32289443038		process: 73/229
# Updating the model...
# Forecasting 1-step from index 73
# result: 55933.715785301334		process: 74/229
# Updating the model...
# Forecasting 1-step from index 74
# result: 56918.22508951152		process: 75/229
# Updating the model...
# Forecasting 1-step from index 75
# result: 62152.91035367273		process: 76/229
# Updating the model...
# Forecasting 1-step from index 76
# result: 60077.63010753118		process: 77/229
# Updating the model...
# Forecasting 1-step from index 77
# result: 69364.51118557516		process: 78/229
# Updating the model...
# Forecasting 1-step from index 78
# result: 64337.35830095077		process: 79/229
# Updating the model...
# Forecasting 1-step from index 79
# result: 55390.16650896885		process: 80/229
# Updating the model...
# Forecasting 1-step from index 80
# result: 48233.58863034712		process: 81/229
# Updating the model...
# Forecasting 1-step from index 81
# result: 48084.61407406031		process: 82/229
# Updating the model...
# Forecasting 1-step from index 82
# result: 57226.90388373211		process: 83/229
# Updating the model...
# Forecasting 1-step from index 83
# result: 65181.20703979721		process: 84/229
# Updating the model...
# Forecasting 1-step from index 84
# result: 64934.62162893162		process: 85/229
# Updating the model...
# Forecasting 1-step from index 85
# result: 54045.18245356965		process: 86/229
# Updating the model...
# Forecasting 1-step from index 86
# result: 58519.1346601767		process: 87/229
# Updating the model...
# Forecasting 1-step from index 87
# result: 65084.745703832035		process: 88/229
# Updating the model...
# Forecasting 1-step from index 88
# result: 57305.024462495574		process: 89/229
# Updating the model...
# Forecasting 1-step from index 89
# result: 68753.39538252089		process: 90/229
# Updating the model...
# Forecasting 1-step from index 90
# result: 58937.331306133034		process: 91/229
# Updating the model...
# Forecasting 1-step from index 91
# result: 58192.91163237992		process: 92/229
# Updating the model...
# Forecasting 1-step from index 92
# result: 58727.080212290864		process: 93/229
# Updating the model...
# Forecasting 1-step from index 93
# result: 64850.01648065562		process: 94/229
# Updating the model...
# Forecasting 1-step from index 94
# result: 52422.53062593065		process: 95/229
# Updating the model...
# Forecasting 1-step from index 95
# result: 60943.90915023304		process: 96/229
# Updating the model...
# Forecasting 1-step from index 96
# result: 72029.90321786677		process: 97/229
# Updating the model...
# Forecasting 1-step from index 97
# result: 62132.80647621076		process: 98/229
# Updating the model...
# Forecasting 1-step from index 98
# result: 43702.925953417594		process: 99/229
# Updating the model...
# Forecasting 1-step from index 99
# result: 57897.87899513805		process: 100/229
# Updating the model...
# Forecasting 1-step from index 100
# result: 62460.09801617314		process: 101/229
# Updating the model...
# Forecasting 1-step from index 101
# result: 52282.92784173743		process: 102/229
# Updating the model...
# Forecasting 1-step from index 102
# result: 61889.21263410511		process: 103/229
# Updating the model...
# Forecasting 1-step from index 103
# result: 62187.455365670765		process: 104/229
# Updating the model...
# Forecasting 1-step from index 104
# result: 67173.32659540516		process: 105/229
# Updating the model...
# Forecasting 1-step from index 105
# result: 77512.13558457431		process: 106/229
# Updating the model...
# Forecasting 1-step from index 106
# result: 70179.10254374325		process: 107/229
# Updating the model...
# Forecasting 1-step from index 107
# result: 69315.77835013934		process: 108/229
# Updating the model...
# Forecasting 1-step from index 108
# result: 73114.46684957108		process: 109/229
# Updating the model...
# Forecasting 1-step from index 109
# result: 65015.281468178015		process: 110/229
# Updating the model...
# Forecasting 1-step from index 110
# result: 78212.32103347035		process: 111/229
# Updating the model...
# Forecasting 1-step from index 111
# result: 71655.1350567286		process: 112/229
# Updating the model...
# Forecasting 1-step from index 112
# result: 81657.0290790056		process: 113/229
# Updating the model...
# Forecasting 1-step from index 113
# result: 65271.75320515213		process: 114/229
# Updating the model...
# Forecasting 1-step from index 114
# result: 79751.60692788428		process: 115/229
# Updating the model...
# Forecasting 1-step from index 115
# result: 70888.1091982592		process: 116/229
# Updating the model...
# Forecasting 1-step from index 116
# result: 71225.02074721758		process: 117/229
# Updating the model...
# Forecasting 1-step from index 117
# result: 91026.78812153114		process: 118/229
# Updating the model...
# Forecasting 1-step from index 118
# result: 85982.50693426927		process: 119/229
# Updating the model...
# Forecasting 1-step from index 119
# result: 77808.56784640106		process: 120/229
# Updating the model...
# Forecasting 1-step from index 120
# result: 78382.50621907004		process: 121/229
# Updating the model...
# Forecasting 1-step from index 121
# result: 89608.12251133364		process: 122/229
# Updating the model...
# Forecasting 1-step from index 122
# result: 76330.88210167595		process: 123/229
# Updating the model...
# Forecasting 1-step from index 123
# result: 82335.72053947629		process: 124/229
# Updating the model...
# Forecasting 1-step from index 124
# result: 79342.83117857965		process: 125/229
# Updating the model...
# Forecasting 1-step from index 125
# result: 75400.0398254221		process: 126/229
# Updating the model...
# Forecasting 1-step from index 126
# result: 83459.13549757293		process: 127/229
# Updating the model...
# Forecasting 1-step from index 127
# result: 75171.66456227878		process: 128/229
# Updating the model...
# Forecasting 1-step from index 128
# result: 70389.99060954998		process: 129/229
# Updating the model...
# Forecasting 1-step from index 129
# result: 72564.89798287397		process: 130/229
# Updating the model...
# Forecasting 1-step from index 130
# result: 66557.63696350408		process: 131/229
# Updating the model...
# Forecasting 1-step from index 131
# result: 69562.24701688121		process: 132/229
# Updating the model...
# Forecasting 1-step from index 132
# result: 70753.6036679374		process: 133/229
# Updating the model...
# Forecasting 1-step from index 133
# result: 64749.34660530125		process: 134/229
# Updating the model...
# Forecasting 1-step from index 134
# result: 75893.11858740004		process: 135/229
# Updating the model...
# Forecasting 1-step from index 135
# result: 73073.61036730625		process: 136/229
# Updating the model...
# Forecasting 1-step from index 136
# result: 63474.162111073165		process: 137/229
# Updating the model...
# Forecasting 1-step from index 137
# result: 70555.42203830264		process: 138/229
# Updating the model...
# Forecasting 1-step from index 138
# result: 68933.5686946551		process: 139/229
# Updating the model...
# Forecasting 1-step from index 139
# result: 78635.35392301081		process: 140/229
# Updating the model...
# Forecasting 1-step from index 140
# result: 66892.20208440167		process: 141/229
# Updating the model...
# Forecasting 1-step from index 141
# result: 62616.05179760043		process: 142/229
# Updating the model...
# Forecasting 1-step from index 142
# result: 59252.98956102027		process: 143/229
# Updating the model...
# Forecasting 1-step from index 143
# result: 67329.42172023916		process: 144/229
# Updating the model...
# Forecasting 1-step from index 144
# result: 61123.37619401704		process: 145/229
# Updating the model...
# Forecasting 1-step from index 145
# result: 80381.69376381484		process: 146/229
# Updating the model...
# Forecasting 1-step from index 146
# result: 68056.16489027058		process: 147/229
# Updating the model...
# Forecasting 1-step from index 147
# result: 56704.296763390485		process: 148/229
# Updating the model...
# Forecasting 1-step from index 148
# result: 59421.10271277781		process: 149/229
# Updating the model...
# Forecasting 1-step from index 149
# result: 55557.29998490463		process: 150/229
# Updating the model...
# Forecasting 1-step from index 150
# result: 55695.47845444347		process: 151/229
# Updating the model...
# Forecasting 1-step from index 151
# result: 61692.18687210499		process: 152/229
# Updating the model...
# Forecasting 1-step from index 152
# result: 52309.30275621306		process: 153/229
# Updating the model...
# Forecasting 1-step from index 153
# result: 65011.76008316137		process: 154/229
# Updating the model...
# Forecasting 1-step from index 154
# result: 67602.00249826105		process: 155/229
# Updating the model...
# Forecasting 1-step from index 155
# result: 55649.6924482231		process: 156/229
# Updating the model...
# Forecasting 1-step from index 156
# result: 66122.97444658897		process: 157/229
# Updating the model...
# Forecasting 1-step from index 157
# result: 63645.557358338905		process: 158/229
# Updating the model...
# Forecasting 1-step from index 158
# result: 62124.93604260039		process: 159/229
# Updating the model...
# Forecasting 1-step from index 159
# result: 70150.67415115291		process: 160/229
# Updating the model...
# Forecasting 1-step from index 160
# result: 57599.29315955522		process: 161/229
# Updating the model...
# Forecasting 1-step from index 161
# result: 66386.91613916718		process: 162/229
# Updating the model...
# Forecasting 1-step from index 162
# result: 67380.2321961542		process: 163/229
# Updating the model...
# Forecasting 1-step from index 163
# result: 59115.26504855092		process: 164/229
# Updating the model...
# Forecasting 1-step from index 164
# result: 59954.30368684538		process: 165/229
# Updating the model...
# Forecasting 1-step from index 165
# result: 62747.55876489269		process: 166/229
# Updating the model...
# Forecasting 1-step from index 166
# result: 46450.86322130478		process: 167/229
# Updating the model...
# Forecasting 1-step from index 167
# result: 62448.5773063018		process: 168/229
# Updating the model...
# Forecasting 1-step from index 168
# result: 57414.2492221714		process: 169/229
# Updating the model...
# Forecasting 1-step from index 169
# result: 65654.1341093698		process: 170/229
# Updating the model...
# Forecasting 1-step from index 170
# result: 52192.78857727284		process: 171/229
# Updating the model...
# Forecasting 1-step from index 171
# result: 72608.42354178747		process: 172/229
# Updating the model...
# Forecasting 1-step from index 172
# result: 67374.86959018925		process: 173/229
# Updating the model...
# Forecasting 1-step from index 173
# result: 66834.45680604476		process: 174/229
# Updating the model...
# Forecasting 1-step from index 174
# result: 66269.59489594353		process: 175/229
# Updating the model...
# Forecasting 1-step from index 175
# result: 61926.931346179605		process: 176/229
# Updating the model...
# Forecasting 1-step from index 176
# result: 71439.47133907113		process: 177/229
# Updating the model...
# Forecasting 1-step from index 177
# result: 71605.8799660914		process: 178/229
# Updating the model...
# Forecasting 1-step from index 178
# result: 64688.3924249353		process: 179/229
# Updating the model...
# Forecasting 1-step from index 179
# result: 61445.64811475678		process: 180/229
# Updating the model...
# Forecasting 1-step from index 180
# result: 63117.31033355357		process: 181/229
# Updating the model...
# Forecasting 1-step from index 181
# result: 66202.52983784197		process: 182/229
# Updating the model...
# Forecasting 1-step from index 182
# result: 66186.0874381574		process: 183/229
# Updating the model...
# Forecasting 1-step from index 183
# result: 69499.8453507948		process: 184/229
# Updating the model...
# Forecasting 1-step from index 184
# result: 54095.74864400734		process: 185/229
# Updating the model...
# Forecasting 1-step from index 185
# result: 59694.851266002035		process: 186/229
# Updating the model...
# Forecasting 1-step from index 186
# result: 60144.017442202065		process: 187/229
# Updating the model...
# Forecasting 1-step from index 187
# result: 70384.05268154261		process: 188/229
# Updating the model...
# Forecasting 1-step from index 188
# result: 59800.006347926144		process: 189/229
# Updating the model...
# Forecasting 1-step from index 189
# result: 64788.609352215644		process: 190/229
# Updating the model...
# Forecasting 1-step from index 190
# result: 74970.32339536073		process: 191/229
# Updating the model...
# Forecasting 1-step from index 191
# result: 65239.407131038606		process: 192/229
# Updating the model...
# Forecasting 1-step from index 192
# result: 66672.36115454824		process: 193/229
# Updating the model...
# Forecasting 1-step from index 193
# result: 67943.93045509796		process: 194/229
# Updating the model...
# Forecasting 1-step from index 194
# result: 66924.91375560783		process: 195/229
# Updating the model...
# Forecasting 1-step from index 195
# result: 55840.335548073606		process: 196/229
# Updating the model...
# Forecasting 1-step from index 196
# result: 49062.589612189564		process: 197/229
# Updating the model...
# Forecasting 1-step from index 197
# result: 73879.15067247994		process: 198/229
# Updating the model...
# Forecasting 1-step from index 198
# result: 72007.0706711969		process: 199/229
# Updating the model...
# Forecasting 1-step from index 199
# result: 67633.59987924706		process: 200/229
# Updating the model...
# Forecasting 1-step from index 200
# result: 56395.80640272226		process: 201/229
# Updating the model...
# Forecasting 1-step from index 201
# result: 54411.664183006185		process: 202/229
# Updating the model...
# Forecasting 1-step from index 202
# result: 60867.77731839976		process: 203/229
# Updating the model...
# Forecasting 1-step from index 203
# result: 47000.43200025872		process: 204/229
# Updating the model...
# Forecasting 1-step from index 204
# result: 63703.84719332013		process: 205/229
# Updating the model...
# Forecasting 1-step from index 205
# result: 58254.95062684003		process: 206/229
# Updating the model...
# Forecasting 1-step from index 206
# result: 66496.95210596218		process: 207/229
# Updating the model...
# Forecasting 1-step from index 207
# result: 62938.97058838639		process: 208/229
# Updating the model...
# Forecasting 1-step from index 208
# result: 56872.136354843984		process: 209/229
# Updating the model...
# Forecasting 1-step from index 209
# result: 58694.35701461872		process: 210/229
# Updating the model...
# Forecasting 1-step from index 210
# result: 59843.761098321214		process: 211/229
# Updating the model...
# Forecasting 1-step from index 211
# result: 67323.13728845453		process: 212/229
# Updating the model...
# Forecasting 1-step from index 212
# result: 61846.35193660336		process: 213/229
# Updating the model...
# Forecasting 1-step from index 213
# result: 64494.87117535546		process: 214/229
# Updating the model...
# Forecasting 1-step from index 214
# result: 65865.59533294837		process: 215/229
# Updating the model...
# Forecasting 1-step from index 215
# result: 57469.70502983379		process: 216/229
# Updating the model...
# Forecasting 1-step from index 216
# result: 70276.11202571426		process: 217/229
# Updating the model...
# Forecasting 1-step from index 217
# result: 64045.29008801621		process: 218/229
# Updating the model...
# Forecasting 1-step from index 218
# result: 73094.68984874515		process: 219/229
# Updating the model...
# Forecasting 1-step from index 219
# result: 63948.30340484611		process: 220/229
# Updating the model...
# Forecasting 1-step from index 220
# result: 60126.43572374417		process: 221/229
# Updating the model...
# Forecasting 1-step from index 221
# result: 77776.42609331067		process: 222/229
# Updating the model...
# Forecasting 1-step from index 222
# result: 70502.27653430327		process: 223/229
# Updating the model...
# Forecasting 1-step from index 223
# result: 67102.60002023166		process: 224/229
# Updating the model...
# Forecasting 1-step from index 224
# result: 61265.77924205791		process: 225/229
# Updating the model...
# Forecasting 1-step from index 225
# result: 65646.41557841912		process: 226/229
# Updating the model...
# Forecasting 1-step from index 226
# result: 76497.2556131673		process: 227/229
# Updating the model...
# Forecasting 1-step from index 227
# result: 78534.30883421005		process: 228/229
# Updating the model...
# Forecasting 1-step from index 228
# result: 61501.03156198542		process: 229/229
# Updating the model...
# Wall time: 1h 34min 45s

# %%
sc1_forecast_inv = inv_boxcox(sc1_forecast, trans_lambdas)

# %%
sc1_forecast_df, __, __ = execute_forecast(sc1_forecast_inv, dtest)
# Out:
# Mean Absolute Error is		: 0.8127236480400265
# Root Mean Squared Error is	: 1.0265834996648502

# %% [markdown]
# ### Forecast scenario 2 : 3 time step

# %%
# %%time
sc2_forecast = period_forecast(model_loc, 3, df_dtest_trans, test_exg)
# Out:
# Forecasting 3-step from index 0
# result: 53447.56411600338		process: 1/229
# result: 55926.614839711656		process: 2/229
# result: 58525.15874334922		process: 3/229
# Updating the model...
# Forecasting 3-step from index 3
# result: 52149.36810889214		process: 4/229
# result: 50557.88850771477		process: 5/229
# result: 66687.51750885205		process: 6/229
# Updating the model...
# Forecasting 3-step from index 6
# result: 58385.576148924476		process: 7/229
# result: 53666.2802871907		process: 8/229
# result: 50309.43571125112		process: 9/229
# Updating the model...
# Forecasting 3-step from index 9
# result: 47814.9854012651		process: 10/229
# result: 47532.04299912137		process: 11/229
# result: 65254.80506808644		process: 12/229
# Updating the model...
# Forecasting 3-step from index 12
# result: 56962.36808829973		process: 13/229
# result: 49391.46044029118		process: 14/229
# result: 55264.812661464355		process: 15/229
# Updating the model...
# Forecasting 3-step from index 15
# result: 65743.07596955226		process: 16/229
# result: 67161.40103012924		process: 17/229
# result: 73050.80050667001		process: 18/229
# Updating the model...
# Forecasting 3-step from index 18
# result: 36429.33849696294		process: 19/229
# result: 44851.089331108575		process: 20/229
# result: 44022.857420936445		process: 21/229
# Updating the model...
# Forecasting 3-step from index 21
# result: 54205.35911911295		process: 22/229
# result: 49986.59244012508		process: 23/229
# result: 58805.33965694608		process: 24/229
# Updating the model...
# Forecasting 3-step from index 24
# result: 64458.37662565642		process: 25/229
# result: 58634.11513833483		process: 26/229
# result: 50230.92890236676		process: 27/229
# Updating the model...
# Forecasting 3-step from index 27
# result: 67587.56447023399		process: 28/229
# result: 66738.55764482226		process: 29/229
# result: 68956.4629705779		process: 30/229
# Updating the model...
# Forecasting 3-step from index 30
# result: 63505.491666713366		process: 31/229
# result: 62638.76088200307		process: 32/229
# result: 52453.818372935806		process: 33/229
# Updating the model...
# Forecasting 3-step from index 33
# result: 74426.87343807724		process: 34/229
# result: 62078.409639644844		process: 35/229
# result: 62547.45422899993		process: 36/229
# Updating the model...
# Forecasting 3-step from index 36
# result: 56803.34111982995		process: 37/229
# result: 59856.540555045314		process: 38/229
# result: 59870.790498674265		process: 39/229
# Updating the model...
# Forecasting 3-step from index 39
# result: 67049.26458167697		process: 40/229
# result: 63281.81562962148		process: 41/229
# result: 59866.69267753457		process: 42/229
# Updating the model...
# Forecasting 3-step from index 42
# result: 51208.78274020963		process: 43/229
# result: 62132.43734305757		process: 44/229
# result: 67631.17205448121		process: 45/229
# Updating the model...
# Forecasting 3-step from index 45
# result: 55477.61188907851		process: 46/229
# result: 63350.375469298306		process: 47/229
# result: 63824.64761934579		process: 48/229
# Updating the model...
# Forecasting 3-step from index 48
# result: 57097.53637969114		process: 49/229
# result: 61802.92884495651		process: 50/229
# result: 54559.02727880025		process: 51/229
# Updating the model...
# Forecasting 3-step from index 51
# result: 66423.82342397312		process: 52/229
# result: 61107.37103858529		process: 53/229
# result: 65261.72907498082		process: 54/229
# Updating the model...
# Forecasting 3-step from index 54
# result: 51294.2195932116		process: 55/229
# result: 52140.90548622435		process: 56/229
# result: 62798.12054337466		process: 57/229
# Updating the model...
# Forecasting 3-step from index 57
# result: 55840.13876570689		process: 58/229
# result: 57302.90628278231		process: 59/229
# result: 60744.2412807209		process: 60/229
# Updating the model...
# Forecasting 3-step from index 60
# result: 64086.72183067512		process: 61/229
# result: 69736.61089562795		process: 62/229
# result: 59746.93251608743		process: 63/229
# Updating the model...
# Forecasting 3-step from index 63
# result: 56954.85749385539		process: 64/229
# result: 58421.56173759623		process: 65/229
# result: 68403.6967540073		process: 66/229
# Updating the model...
# Forecasting 3-step from index 66
# result: 61245.79597052816		process: 67/229
# result: 64286.145133354665		process: 68/229
# result: 44136.05746243021		process: 69/229
# Updating the model...
# Forecasting 3-step from index 69
# result: 54746.424412187815		process: 70/229
# result: 54655.397523735606		process: 71/229
# result: 64523.418365758844		process: 72/229
# Updating the model...
# Forecasting 3-step from index 72
# result: 49779.44445820642		process: 73/229
# result: 54393.530951380686		process: 74/229
# result: 60003.50527205984		process: 75/229
# Updating the model...
# Forecasting 3-step from index 75
# result: 62155.27111928609		process: 76/229
# result: 56838.85770872338		process: 77/229
# result: 57924.29008109867		process: 78/229
# Updating the model...
# Forecasting 3-step from index 78
# result: 64337.87478380567		process: 79/229
# result: 64315.805015102946		process: 80/229
# result: 58074.83615030367		process: 81/229
# Updating the model...
# Forecasting 3-step from index 81
# result: 48082.42659470637		process: 82/229
# result: 48513.31045604348		process: 83/229
# result: 53289.64550290171		process: 84/229
# Updating the model...
# Forecasting 3-step from index 84
# result: 64937.12364455491		process: 85/229
# result: 58382.16391828393		process: 86/229
# result: 58659.01067148108		process: 87/229
# Updating the model...
# Forecasting 3-step from index 87
# result: 65087.21343596984		process: 88/229
# result: 61237.552203836196		process: 89/229
# result: 64224.687806081485		process: 90/229
# Updating the model...
# Forecasting 3-step from index 90
# result: 58937.65402772461		process: 91/229
# result: 56860.156017669666		process: 92/229
# result: 55499.298728101465		process: 93/229
# Updating the model...
# Forecasting 3-step from index 93
# result: 64850.83921949024		process: 94/229
# result: 50209.611109152		process: 95/229
# result: 58522.979201066715		process: 96/229
# Updating the model...
# Forecasting 3-step from index 96
# result: 72029.36873672779		process: 97/229
# result: 69642.9947780324		process: 98/229
# result: 53619.003611580476		process: 99/229
# Updating the model...
# Forecasting 3-step from index 99
# result: 57908.13919887811		process: 100/229
# result: 66205.47176256208		process: 101/229
# result: 60257.12536993481		process: 102/229
# Updating the model...
# Forecasting 3-step from index 102
# result: 61891.424404250065		process: 103/229
# result: 58825.321191774965		process: 104/229
# result: 58375.65311648121		process: 105/229
# Updating the model...
# Forecasting 3-step from index 105
# result: 77514.58478489803		process: 106/229
# result: 76058.8535299027		process: 107/229
# result: 72811.69666955151		process: 108/229
# Updating the model...
# Forecasting 3-step from index 108
# result: 73115.24077203372		process: 109/229
# result: 63729.19817488995		process: 110/229
# result: 74950.35667210542		process: 111/229
# Updating the model...
# Forecasting 3-step from index 111
# result: 71656.28348680805		process: 112/229
# result: 75465.66015080834		process: 113/229
# result: 69032.21388836704		process: 114/229
# Updating the model...
# Forecasting 3-step from index 114
# result: 79750.49327194745		process: 115/229
# result: 69757.4152230943		process: 116/229
# result: 67397.14975040015		process: 117/229
# Updating the model...
# Forecasting 3-step from index 117
# result: 91026.69087024948		process: 118/229
# result: 82499.51822379163		process: 119/229
# result: 70816.40817213891		process: 120/229
# Updating the model...
# Forecasting 3-step from index 120
# result: 78366.04491112557		process: 121/229
# result: 86616.00627283266		process: 122/229
# result: 74415.9180807221		process: 123/229
# Updating the model...
# Forecasting 3-step from index 123
# result: 82325.49566021786		process: 124/229
# result: 81659.5848210351		process: 125/229
# result: 82064.6860464777		process: 126/229
# Updating the model...
# Forecasting 3-step from index 126
# result: 83448.34783616944		process: 127/229
# result: 87301.61847600406		process: 128/229
# result: 80910.36162874413		process: 129/229
# Updating the model...
# Forecasting 3-step from index 129
# result: 72575.33639869833		process: 130/229
# result: 74448.18065910015		process: 131/229
# result: 70437.61658355324		process: 132/229
# Updating the model...
# Forecasting 3-step from index 132
# result: 70756.38077458498		process: 133/229
# result: 67001.4143089411		process: 134/229
# result: 71121.88967271904		process: 135/229
# Updating the model...
# Forecasting 3-step from index 135
# result: 73080.73667686993		process: 136/229
# result: 67670.59869706392		process: 137/229
# result: 72881.08150739652		process: 138/229
# Updating the model...
# Forecasting 3-step from index 138
# result: 68937.82501196649		process: 139/229
# result: 76290.52654925821		process: 140/229
# result: 69555.1593074467		process: 141/229
# Updating the model...
# Forecasting 3-step from index 141
# result: 62617.66333664671		process: 142/229
# result: 63166.33334794395		process: 143/229
# result: 64679.51383859888		process: 144/229
# Updating the model...
# Forecasting 3-step from index 144
# result: 61125.72141353874		process: 145/229
# result: 71988.35803395776		process: 146/229
# result: 63349.60678055086		process: 147/229
# Updating the model...
# Forecasting 3-step from index 147
# result: 56699.936765974606		process: 148/229
# result: 61879.00421759628		process: 149/229
# result: 65916.4745341041		process: 150/229
# Updating the model...
# Forecasting 3-step from index 150
# result: 55694.33842525164		process: 151/229
# result: 64216.9214855718		process: 152/229
# result: 55180.22701999504		process: 153/229
# Updating the model...
# Forecasting 3-step from index 153
# result: 65014.86483893726		process: 154/229
# result: 66534.03132666358		process: 155/229
# result: 56178.710732089516		process: 156/229
# Updating the model...
# Forecasting 3-step from index 156
# result: 66127.4496053126		process: 157/229
# result: 68931.00919401471		process: 158/229
# result: 69752.59424971708		process: 159/229
# Updating the model...
# Forecasting 3-step from index 159
# result: 70150.26662472288		process: 160/229
# result: 61151.78785275269		process: 161/229
# result: 65101.730800684774		process: 162/229
# Updating the model...
# Forecasting 3-step from index 162
# result: 67385.06480471522		process: 163/229
# result: 65792.0010020027		process: 164/229
# result: 55023.97952915434		process: 165/229
# Updating the model...
# Forecasting 3-step from index 165
# result: 62757.827349428735		process: 166/229
# result: 50862.086440331215		process: 167/229
# result: 55600.4466980407		process: 168/229
# Updating the model...
# Forecasting 3-step from index 168
# result: 57407.012394689744		process: 169/229
# result: 66606.77340855853		process: 170/229
# result: 60236.43577445151		process: 171/229
# Updating the model...
# Forecasting 3-step from index 171
# result: 72606.05676072143		process: 172/229
# result: 68168.95155097941		process: 173/229
# result: 71083.52767117882		process: 174/229
# Updating the model...
# Forecasting 3-step from index 174
# result: 66265.57758491169		process: 175/229
# result: 68062.26286953174		process: 176/229
# result: 65621.90796475705		process: 177/229
# Updating the model...
# Forecasting 3-step from index 177
# result: 71600.95482729457		process: 178/229
# result: 71107.32351264391		process: 179/229
# result: 61000.2883115197		process: 180/229
# Updating the model...
# Forecasting 3-step from index 180
# result: 63116.26887654247		process: 181/229
# result: 59881.82534263978		process: 182/229
# result: 63231.312224447865		process: 183/229
# Updating the model...
# Forecasting 3-step from index 183
# result: 69496.60694132125		process: 184/229
# result: 65358.40476084149		process: 185/229
# result: 66248.06121836908		process: 186/229
# Updating the model...
# Forecasting 3-step from index 186
# result: 60140.839661233695		process: 187/229
# result: 64106.227713064574		process: 188/229
# result: 61012.67347584629		process: 189/229
# Updating the model...
# Forecasting 3-step from index 189
# result: 64787.134360020005		process: 190/229
# result: 74359.37726764285		process: 191/229
# result: 67739.8061914827		process: 192/229
# Updating the model...
# Forecasting 3-step from index 192
# result: 66669.96427581261		process: 193/229
# result: 72449.33659812245		process: 194/229
# result: 68507.6345777645		process: 195/229
# Updating the model...
# Forecasting 3-step from index 195
# result: 55839.56646077086		process: 196/229
# result: 45529.95331832732		process: 197/229
# result: 64003.94920356662		process: 198/229
# Updating the model...
# Forecasting 3-step from index 198
# result: 72001.64417721232		process: 199/229
# result: 74196.55632163202		process: 200/229
# result: 64692.93211870181		process: 201/229
# Updating the model...
# Forecasting 3-step from index 201
# result: 54408.912367974575		process: 202/229
# result: 63259.411011775315		process: 203/229
# result: 52132.36336590207		process: 204/229
# Updating the model...
# Forecasting 3-step from index 204
# result: 63708.41526623365		process: 205/229
# result: 53342.274887606414		process: 206/229
# result: 60065.83434600015		process: 207/229
# Updating the model...
# Forecasting 3-step from index 207
# result: 62944.35123699156		process: 208/229
# result: 57591.64650262071		process: 209/229
# result: 57870.00912676793		process: 210/229
# Updating the model...
# Forecasting 3-step from index 210
# result: 59838.69044767603		process: 211/229
# result: 59081.17157064992		process: 212/229
# result: 53378.243280930175		process: 213/229
# Updating the model...
# Forecasting 3-step from index 213
# result: 64488.32889233015		process: 214/229
# result: 66673.5524291338		process: 215/229
# result: 62060.516632999774		process: 216/229
# Updating the model...
# Forecasting 3-step from index 216
# result: 70267.4760276861		process: 217/229
# result: 63931.02419409126		process: 218/229
# result: 66434.47106537396		process: 219/229
# Updating the model...
# Forecasting 3-step from index 219
# result: 63948.56249726948		process: 220/229
# result: 59705.00598410517		process: 221/229
# result: 73529.50426465465		process: 222/229
# Updating the model...
# Forecasting 3-step from index 222
# result: 70494.83884558303		process: 223/229
# result: 67081.72175300801		process: 224/229
# result: 59352.41775240968		process: 225/229
# Updating the model...
# Forecasting 3-step from index 225
# result: 65627.3168437407		process: 226/229
# result: 72910.96340334167		process: 227/229
# result: 73259.19957209525		process: 228/229
# Updating the model...
# Forecasting 1-step from index 228
# result: 61506.88031696485		process: 229/229
# Updating the model...
# Wall time: 29min 30s

# %%
sc2_forecast_inv = inv_boxcox(sc2_forecast, trans_lambdas)

# %%
sc2_forecast_df, __, __ = execute_forecast(sc2_forecast_inv, dtest)
# Out:
# Mean Absolute Error is		: 0.8562722071814892
# Root Mean Squared Error is	: 1.0716383674897778

# %% [markdown]
# ### Forecast scenario 3 : 7 time step

# %%
# %%time
sc3_forecast = period_forecast(model_loc, 7, df_dtest_trans, test_exg)
# Out:
# Forecasting 7-step from index 0
# result: 53447.56411600337		process: 1/229
# result: 55926.614839711656		process: 2/229
# result: 58525.158743349224		process: 3/229
# result: 54750.029664699105		process: 4/229
# result: 50493.81947011877		process: 5/229
# result: 66610.72437747353		process: 6/229
# result: 61819.8491086723		process: 214/229
# result: 63258.120992366596		process: 215/229
# result: 59059.60378076541		process: 216/229
# result: 66891.51634815174		process: 217/229
# Updating the model...
# Forecasting 7-step from index 217
# result: 64039.85696511006		process: 218/229
# result: 66482.03225659378		process: 219/229
# result: 60831.21251074847		process: 220/229
# result: 57079.00671166647		process: 221/229
# result: 71249.23359156925		process: 222/229
# result: 70391.65401654122		process: 223/229
# result: 65349.988177449224		process: 224/229
# Updating the model...
# Forecasting 5-step from index 224
# result: 61266.13595128961		process: 225/229
# result: 71518.79471049769		process: 226/229
# result: 75562.3333654473		process: 227/229
# result: 75545.99861987859		process: 228/229
# result: 74520.63855753116		process: 229/229
# Updating the model...
# Wall time: 13min 51s

# %%
sc3_forecast_inv = inv_boxcox(sc3_forecast, trans_lambdas)

# %%
sc3_forecast_df, __, __ = execute_forecast(sc3_forecast_inv, dtest)
# Out:
# Mean Absolute Error is		: 0.8891353893716892
# Root Mean Squared Error is	: 1.091863554524994

# %% [markdown]
# # Collecting All Predictions Scenario Result

# %%
def plot_forecasts_result(res_df):
    title = 'Peramalan ' + ATTR_NAME + ' ARIMA'
    
    plt.figure(figsize=(18,8))
    plt.title(title)
    plt.plot(res_df['scn-1'], 'r-', label='1-step forecast')
    plt.plot(res_df['scn-2'], 'b-', label='3-step forecast')
    plt.plot(res_df['scn-3'], 'g-', label='7-step forecast')
    plt.plot(res_df['Actuals'], color='black', linestyle=':' , label='Actuals')
    plt.legend()

# %%
def col_forcasts_err(res_df):
    for col in [x for x in range(len(forecasts_result.columns)-1)]:
        col_name = res_df.columns[col]
        MAE = mean_absolute_error(res_df['Actuals'], res_df[col_name])
        RMSE = sqrt(mean_squared_error(res_df['Actuals'], res_df[col_name]))
        print('Error for ', col_name)
        print(f'Mean Absolute Error is\t\t: {MAE}')
        print(f'Root Mean Squared Error is\t: {RMSE}')
        print()

# %%
sc1_df_cp = sc1_forecast_df.copy()
sc1_df_cp.columns = ['scn-1', 'Actuals']

sc2_df_cp = sc2_forecast_df.copy()
sc2_df_cp.columns = ['scn-2', 'Actuals']

sc3_df_cp = sc3_forecast_df.copy()
sc3_df_cp.columns = ['scn-3', 'Actuals']

# %%
forecasts_result = pd.concat([sc1_df_cp[[sc1_df_cp.columns[0]]],
                              sc2_df_cp[[sc2_df_cp.columns[0]]],
                              sc3_df_cp[[sc3_df_cp.columns[0]]],
                              sc1_df_cp[[sc3_df_cp.columns[1]]]
                             ],
                               axis='columns')

# %%
plot_forecasts_result(forecasts_result)

# %%
col_forcasts_err(forecasts_result)
# Out:
# Error for  scn-1
# Mean Absolute Error is		: 0.8127236480400265
# Root Mean Squared Error is	: 1.0265834996648502
#
# Error for  scn-2
# Mean Absolute Error is		: 0.8562722071814892
# Root Mean Squared Error is	: 1.0716383674897778
#
# Error for  scn-3
# Mean Absolute Error is		: 0.8891353893716892
# Root Mean Squared Error is	: 1.091863554524994

# %% [markdown]
# ## Saving forecasts result

# %%
forecasts_result.to_csv('ARIMA_results/'+ATTR_NOW+'.csv')
